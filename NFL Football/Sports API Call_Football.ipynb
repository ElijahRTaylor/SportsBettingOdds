# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'basketball_ncaab', 'group': 'Basketball', 'title': 'NCAAB', 'description': 'US College Basketball', 'active': True, 'has_outrights': False}, {'key': 'cricket_international_t20', 'group': 'Cricket', 'title': 'International Twenty20', 'description': 'International Twenty20', 'active': True, 'has_outrights': False}, {'key': 'cricket_odi', 'group': 'Cricket', 'title': 'One Day Internationals', 'description': 'One Day Internationals', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_china_superleague', 'group': 'Soccer', 'title': 'Super League - China', 'description': 'Chinese Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_efl_champ', 'group': 'Soccer', 'title': 'Championship', 'description': 'EFL Championship', 'active': True, 'has_outrights': False}, {'key': 'soccer_england_league1', 'group': 'Soccer ...
# Number of events: 13
# [{'id': 'e4cb60c1cd96813bbf67450007cb2a10', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2022-11-15T01:15:00Z', 'home_team': 'Philadelphia Eagles', 'away_team': 'Washington Commanders', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-11-14T05:51:46Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -115, 'point': -10.5}, {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-11-14T05:51:53Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -115, 'point': -10.5}, {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-11-14T05:54:40Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2022-11-14T05:54:49Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -111, 'point': -10.5}, {'name': 'Washington Commanders', 'price': -111, 'point': 10.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-11-14T05:52:10Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2022-11-14T05:51:48Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2022-11-14T05:52:46Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -105, 'point': -10.5}, {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-11-14T05:52:10Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-11-14T05:51:45Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2022-11-14T05:52:03Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2022-11-14T05:47:17Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -105, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -115, 'point': 11.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-11-14T05:52:20Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2022-11-14T05:52:22Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-11-14T05:52:10Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Philadelphia Eagles', 'price': -110, 'point': -11.0}, {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-11-14T05:55:11Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Phila ...
# Remaining requests 498
# Used requests 2

# %%
# odds_json

odds_json
# Out:
# [{'id': 'e4cb60c1cd96813bbf67450007cb2a10',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-15T01:15:00Z',
#   'home_team': 'Philadelphia Eagles',
#   'away_team': 'Washington Commanders',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -115,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -115,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -111,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -111, 'point': 10.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -105,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -105,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -115, 'point': 11.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -109,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -109, 'point': 11.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -107,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -107, 'point': 11.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-14T05:52:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -109,
#         'point': -11.0},
#        {'name': 'Washington Commanders', 'price': -109, 'point': 11.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-14T05:51:42Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -118,
#         'point': -10.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': 10.5}]}]}]},
#  {'id': 'e0798499a67017b5837ab3fb09e24777',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-18T01:15:00Z',
#   'home_team': 'Green Bay Packers',
#   'away_team': 'Tennessee Titans',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': 100, 'point': 2.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 2.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -107, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -103, 'point': 2.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -108, 'point': 2.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -108, 'point': 2.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -112, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -109, 'point': 2.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -108, 'point': 2.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -108, 'point': 2.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.0},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -103, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -115, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -2.5},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 2.5}]}]}]},
#  {'id': '449d4f6af92880469d4d3405e34042e3',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Atlanta Falcons',
#   'away_team': 'Chicago Bears',
#   'bookmakers': [{'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -112, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -112, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': 100, 'point': -3.5},
#        {'name': 'Chicago Bears', 'price': -120, 'point': 3.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -125, 'point': -2.5},
#        {'name': 'Chicago Bears', 'price': 104, 'point': 2.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -112, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -112, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -121, 'point': -2.5},
#        {'name': 'Chicago Bears', 'price': 110, 'point': 2.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -105, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -115, 'point': 3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -107, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -107, 'point': 3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -109, 'point': 3.0}]}]}]},
#  {'id': 'f53af7a0ca9789f19b3ee9af25cd9d93',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Baltimore Ravens',
#   'away_team': 'Carolina Panthers',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -102, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -108, 'point': 12.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -108, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -114, 'point': 12.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -105, 'point': -13.0},
#        {'name': 'Carolina Panthers', 'price': -115, 'point': 13.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -107, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -107, 'point': 12.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -109, 'point': 12.5}]}]}]},
#  {'id': '0e207b9097d05f4e0c29eaa51dfba378',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Buffalo Bills',
#   'away_team': 'Cleveland Browns',
#   'bookmakers': [{'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 9.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -111, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -111, 'point': 9.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 9.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 9.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 9.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 9.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -107, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -107, 'point': 8.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -109, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -109, 'point': 8.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 9.0}]}]}]},
#  {'id': 'b879f75b3c85ed1c8a686acaa9c03d9a',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New York Giants',
#   'away_team': 'Detroit Lions',
#   'bookmakers': [{'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -108, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -102, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 4.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -107, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -107, 'point': -3.5}]}]}]},
#  {'id': '13609957f97b2469d6a01db2ad42a053',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Houston Texans',
#   'away_team': 'Washington Commanders',
#   'bookmakers': [{'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -2.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -111, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -111, 'point': -2.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -106, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -114, 'point': -2.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -105, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': -2.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -105, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -121, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': 102, 'point': -2.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 2.5},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -2.5}]}]}]},
#  {'id': '165cbe2f28ce9b22f4dda8169843f848',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Indianapolis Colts',
#   'away_team': 'Philadelphia Eagles',
#   'bookmakers': [{'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -112, 'point': -9.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -106, 'point': 8.5},
#        {'name': 'Philadelphia Eagles', 'price': -114, 'point': -8.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 9.0},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -9.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -114, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -108, 'point': -9.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -112, 'point': -9.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -112, 'point': -9.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts',
#         'price': -125,
#         'point': 10.5},
#        {'name': 'Philadelphia Eagles', 'price': 105, 'point': -10.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -105, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -115, 'point': -9.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 8.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -8.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -112, 'point': -9.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -108, 'point': 9.5},
#        {'name': 'Philadelphia Eagles', 'price': -102, 'point': -9.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 9.0},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -9.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 9.0},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -9.0}]}]}]},
#  {'id': '45a5068369254d1d6c1b925e3792068d',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New Orleans Saints',
#   'away_team': 'Los Angeles Rams',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -115, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -112, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -2.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -105, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -114, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -106, 'point': -3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -112, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -2.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -112, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -2.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': 100, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -112, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -2.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 2.5},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -105, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -113, 'point': -3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -107, 'point': 3.0},
#        {'name': 'New Orleans Saints', 'price': -107, 'point': -3.0}]}]}]},
#  {'id': '52229c7e0378a451ccd345fe8de45a52',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New England Patriots',
#   'away_team': 'New York Jets',
#   'bookmakers': [{'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -109,
#         'point': -4.0},
#        {'name': 'New York Jets', 'price': -112, 'point': 4.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -109,
#         'point': -4.0},
#        {'name': 'New York Jets', 'price': -112, 'point': 4.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -115,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -105, 'point': 3.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -111,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -111, 'point': 3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -109,
#         'point': -4.0},
#        {'name': 'New York Jets', 'price': -112, 'point': 4.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
# ...
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -105,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -105, 'point': 3.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -107, 'point': 3.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -107,
#         'point': -3.5},
#        {'name': 'New York Jets', 'price': -107, 'point': 3.5}]}]}]},
#  {'id': '7e0b980531f449fae861daf30b37116a',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T21:05:00Z',
#   'home_team': 'Denver Broncos',
#   'away_team': 'Las Vegas Raiders',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -115, 'point': -2.5},
#        {'name': 'Las Vegas Raiders', 'price': -105, 'point': 2.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': 100, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -120, 'point': 3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -115, 'point': 3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -115, 'point': 3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -115, 'point': 3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': 100, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -120, 'point': 3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -115, 'point': -2.5},
#        {'name': 'Las Vegas Raiders', 'price': -105, 'point': 2.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': 105, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -116, 'point': 3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -115, 'point': -2.5},
#        {'name': 'Las Vegas Raiders', 'price': -105, 'point': 2.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -109, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -107, 'point': -3.0},
#        {'name': 'Las Vegas Raiders', 'price': -107, 'point': 3.0}]}]}]},
#  {'id': '7b59ad0c31af31b823f5ed7455f7ac53',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T21:25:00Z',
#   'home_team': 'Pittsburgh Steelers',
#   'away_team': 'Cincinnati Bengals',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -105,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -105, 'point': 5.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -111,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -111, 'point': 5.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -107,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -112, 'point': 5.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -107,
#         'point': -5.0},
#        {'name': 'Pittsburgh Steelers', 'price': -107, 'point': 5.0}]}]}]},
#  {'id': '45cc9feb5cd8b7d9dd2eafe64ceef1d3',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T21:25:00Z',
#   'home_team': 'Minnesota Vikings',
#   'away_team': 'Dallas Cowboys',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-14T05:54:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -111, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -111, 'point': 2.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-14T05:54:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 2.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-14T05:47:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-14T05:51:45Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 2.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-14T05:52:22Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-14T05:51:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-14T05:51:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 2.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-14T05:52:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 2.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-14T05:52:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -105, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -105, 'point': 2.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-14T05:55:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-14T05:52:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-14T05:51:53Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': 102, 'point': -2.5},
#        {'name': 'Minnesota Vikings', 'price': -121, 'point': 2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-14T05:52:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -107, 'point': -2.0},
#        {'name': 'Minnesota Vikings', 'price': -107, 'point': 2.0}]}]}]}]

# %%
len(odds_json)
# Out:
# 13

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Philadelphia Eagles -10.5
# ----------------------
# Washington Commanders 10.5
#
# ----------------------
# Green Bay Packers -2.5
# ----------------------
# Tennessee Titans 2.5
#
# ----------------------
# Atlanta Falcons -3.0
# ----------------------
# Chicago Bears 3.0
#
# ----------------------
# Baltimore Ravens -12.5
# ----------------------
# Carolina Panthers 12.5
#
# ----------------------
# Buffalo Bills -9.0
# ----------------------
# Cleveland Browns 9.0
#
# ----------------------
# Detroit Lions 4.0
# ----------------------
# New York Giants -4.0
#
# ----------------------
# Houston Texans 2.5
# ----------------------
# Washington Commanders -2.5
#
# ----------------------
# Indianapolis Colts 9.5
# ----------------------
# Philadelphia Eagles -9.5
#
# ----------------------
# Los Angeles Rams 3.0
# ----------------------
# New Orleans Saints -3.0
#
# ----------------------
# New England Patriots -4.0
# ----------------------
# New York Jets 4.0
#
# ----------------------
# Denver Broncos -2.5
# ----------------------
# Las Vegas Raiders 2.5
#
# ----------------------
# Cincinnati Bengals -4.5
# ----------------------
# Pittsburgh Steelers 4.5
#
# ----------------------
# Dallas Cowboys -2.0
# ----------------------
# Minnesota Vikings 2.0

# %%
print(odds_json[0]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# Atlanta Falcons

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Philadelphia Eagles -10.5
# ----------------------
# Washington Commanders 10.5
#
# ----------------------
# Green Bay Packers -2.5
# ----------------------
# Tennessee Titans 2.5
#
# ----------------------
# Atlanta Falcons -3.0
# ----------------------
# Chicago Bears 3.0
#
# ----------------------
# Baltimore Ravens -12.5
# ----------------------
# Carolina Panthers 12.5
#
# ----------------------
# Buffalo Bills -9.0
# ----------------------
# Cleveland Browns 9.0
#
# ----------------------
# Detroit Lions 4.0
# ----------------------
# New York Giants -4.0
#
# ----------------------
# Houston Texans 2.5
# ----------------------
# Washington Commanders -2.5
#
# ----------------------
# Indianapolis Colts 9.5
# ----------------------
# Philadelphia Eagles -9.5
#
# ----------------------
# Los Angeles Rams 3.0
# ----------------------
# New Orleans Saints -3.0
#
# ----------------------
# New England Patriots -4.0
# ----------------------
# New York Jets 4.0
#
# ----------------------
# Denver Broncos -2.5
# ----------------------
# Las Vegas Raiders 2.5
#
# ----------------------
# Cincinnati Bengals -4.5
# ----------------------
# Pittsburgh Steelers 4.5
#
# ----------------------
# Dallas Cowboys -2.0
# ----------------------
# Minnesota Vikings 2.0

# %%
print(odds_json[9]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# New England Patriots

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# ['Philadelphia Eagles',
#  'Green Bay Packers',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'New York Giants',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'New Orleans Saints',
#  'New England Patriots',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings']

# %%
odds_json[0]["home_team"]
# Out:
# 'Philadelphia Eagles'

# %%
home_team_spread=[]

for x in range(len(odds_json)):
    home_spread = odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"]
    if home_spread not in home_team_spread:
                 home_team_spread.append(home_spread)
                     
home_team_spread
# Out:
# [-10.5, -2.5, -3.0, -12.5, -9.0, 4.0, 2.5, 9.5, 3.0, -4.0, -4.5, -2.0]

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# ['Washington Commanders',
#  'Tennessee Titans',
#  'Chicago Bears',
#  'Carolina Panthers',
#  'Cleveland Browns',
#  'Detroit Lions',
#  'Philadelphia Eagles',
#  'Los Angeles Rams',
#  'New York Jets',
#  'Las Vegas Raiders',
#  'Cincinnati Bengals',
#  'Dallas Cowboys']

# %%
away_team_spread=[]

for x in range(len(odds_json)):
    away_spread = odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"]
    if away_spread not in away_team_spread:
                 away_team_spread.append(away_spread)
            
away_team_spread
# Out:
# [10.5, 2.5, 3.0, 12.5, 9.0, -4.0, -2.5, -9.5, -3.0, 4.0, 4.5, 2.0]

# %%
# # fave_team_spread=[]
# # sportsbook_list=[]

# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     if fave_spread not in fave_team_spread:
# #         fave_team_spread.append(fave_spread)
# #         sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     if dog_spread not in dog_team_spread:
# #         dog_team_spread.append(dog_spread)
# #         sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# # print(dog_team_spread)


# # fave_team_spread=[]
sportsbook_list=[]

# odds_json[0]["bookmakers"]
for x in range(len(odds_json[0]["bookmakers"])):
    sportsbook=odds_json[0]["bookmakers"][x]["title"]
    sportsbook_list.append(sportsbook)

print(sportsbook_list)
    
    




# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     fave_team_spread.append(fave_spread)
# #     sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     dog_team_spread.append(dog_spread)
# #     sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# print(dog_team_spread)
# Out:
# ['FanDuel', 'DraftKings', 'Barstool Sportsbook', 'BetOnline.ag', 'SugarHouse', 'SuperBook', 'LowVig.ag', 'BetRivers', 'William Hill (US)', 'Unibet', 'Bovada', 'MyBookie.ag', 'BetUS', 'WynnBET', 'BetMGM', 'Circa Sports', 'PointsBet (US)', 'GTbets', 'Intertops', 'FOX Bet']

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Philadelphia Eagles',
#  'Green Bay Packers',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'New York Giants',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'New Orleans Saints',
#  'New England Patriots',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings']

# %%
FD_Daily_Spread_Dict={"Home_Team":home_team_list, "Home Team Spread":home_team_spread,"Away_Team":away_team_list, "Away Team Spread":away_team_spread}
FD_Daily_Spread_Dict
# Out:
# {'Home_Team': ['Philadelphia Eagles',
#   'Green Bay Packers',
#   'Atlanta Falcons',
#   'Baltimore Ravens',
#   'Buffalo Bills',
#   'New York Giants',
#   'Houston Texans',
#   'Indianapolis Colts',
#   'New Orleans Saints',
#   'New England Patriots',
#   'Denver Broncos',
#   'Pittsburgh Steelers',
#   'Minnesota Vikings'],
#  'Home Team Spread': [-10.5,
#   -2.5,
#   -3.0,
#   -12.5,
#   -9.0,
#   4.0,
#   2.5,
#   9.5,
#   3.0,
#   -4.0,
#   -4.5,
#   -2.0],
#  'Away_Team': ['Washington Commanders',
#   'Tennessee Titans',
#   'Chicago Bears',
#   'Carolina Panthers',
#   'Cleveland Browns',
#   'Detroit Lions',
#   'Philadelphia Eagles',
#   'Los Angeles Rams',
#   'New York Jets',
#   'Las Vegas Raiders',
#   'Cincinnati Bengals',
#   'Dallas Cowboys'],
#  'Away Team Spread': [10.5,
#   2.5,
#   3.0,
#   12.5,
#   9.0,
#   -4.0,
#   -2.5,
#   -9.5,
#   -3.0,
#   4.0,
#   4.5,
#   2.0]}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['FanDuel',
#  'DraftKings',
#  'Barstool Sportsbook',
#  'BetOnline.ag',
#  'SugarHouse',
#  'SuperBook',
#  'LowVig.ag',
#  'BetRivers',
#  'William Hill (US)',
#  'Unibet',
#  'Bovada',
#  'MyBookie.ag',
#  'BetUS',
#  'WynnBET',
#  'BetMGM',
#  'Circa Sports',
#  'PointsBet (US)',
#  'GTbets',
#  'Intertops',
#  'FOX Bet']

# %%
# This layout is perfect for volume bettors who bet smaller units across multiple games

SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_19420/2524627083.py in <module>
#       1 # This layout is perfect for volume bettors who bet smaller units across multiple games
#       2
# ----> 3 SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
#       4 SB_NBA_Odds_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
# Create the output file (CSV).
output_data_file = "NBA_Basketball_4.5.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
