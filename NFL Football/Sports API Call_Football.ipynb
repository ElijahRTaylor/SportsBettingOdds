# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'basketball_ncaab', 'group': 'Basketball', 'title': 'NCAAB', 'description': 'US College Basketball', 'active': True, 'has_outrights': False}, {'key': 'cricket_big_bash', 'group': 'Cricket', 'title': 'Big Bash', 'description': 'Big Bash League', 'active': True, 'has_outrights': False}, {'key': 'cricket_international_t20', 'group': 'Cricket', 'title': 'International Twenty20', 'description': 'International Twenty20', 'active': True, 'has_outrights': False}, {'key': 'cricket_odi', 'group': 'Cricket', 'title': 'One Day Internationals', 'description': 'One Day Internationals', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_china_superleague', 'group': 'Soccer', 'title': 'Super League - China', 'description': 'Chinese Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_efl_champ', 'group': 'Soccer', 'title' ...
# Number of events: 14
# [{'id': 'e0798499a67017b5837ab3fb09e24777', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2022-11-18T01:15:00Z', 'home_team': 'Green Bay Packers', 'away_team': 'Tennessee Titans', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-11-16T05:24:57Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -110, 'point': 3.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-11-16T05:25:08Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -107, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -107, 'point': 3.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2022-11-16T05:27:33Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -110, 'point': 3.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2022-11-16T05:25:26Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-11-16T05:25:25Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-11-16T05:24:20Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-11-16T05:25:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2022-11-16T05:28:59Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-11-16T05:27:38Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-11-16T05:28:54Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -120, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2022-11-16T05:28:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -120, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2022-11-16T05:24:19Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-11-16T05:27:52Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-11-16T05:24:09Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'circasports', 'title': 'Circa Sports', 'last_update': '2022-11-16T05:29:15Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -3.0}, {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}, {'key': 'myb ...
# Remaining requests 496
# Used requests 4

# %%
# odds_json

odds_json
# Out:
# [{'id': 'e0798499a67017b5837ab3fb09e24777',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-18T01:15:00Z',
#   'home_team': 'Green Bay Packers',
#   'away_team': 'Tennessee Titans',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -107, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -107, 'point': 3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -110, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -120, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -120, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -117, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -113, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -119, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': 101, 'point': 3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -118, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Green Bay Packers', 'price': -115, 'point': -3.0},
#        {'name': 'Tennessee Titans', 'price': -105, 'point': 3.0}]}]}]},
#  {'id': '449d4f6af92880469d4d3405e34042e3',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Atlanta Falcons',
#   'away_team': 'Chicago Bears',
#   'bookmakers': [{'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -113, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -108, 'point': 3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -118, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -104, 'point': 3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -113, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -108, 'point': 3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -119, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -102, 'point': 3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -113, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -108, 'point': 3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -120, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -113, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -108, 'point': 3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -114, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': 103, 'point': 3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -120, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -118, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': 100, 'point': 3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -114, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -104, 'point': 3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -120, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -115, 'point': -3.0},
#        {'name': 'Chicago Bears', 'price': -105, 'point': 3.0}]}]}]},
#  {'id': 'f53af7a0ca9789f19b3ee9af25cd9d93',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Baltimore Ravens',
#   'away_team': 'Carolina Panthers',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -105, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -105, 'point': 12.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 12.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 12.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -111, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -111, 'point': 12.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 12.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': 105, 'point': -13.5},
#        {'name': 'Carolina Panthers', 'price': -125, 'point': 13.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -107, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -107, 'point': 12.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 12.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -112, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -107, 'point': 12.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -109, 'point': 12.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -12.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 12.0}]}]}]},
#  {'id': '0e207b9097d05f4e0c29eaa51dfba378',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Buffalo Bills',
#   'away_team': 'Cleveland Browns',
#   'bookmakers': [{'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 8.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 8.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 8.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -115, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 8.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 100, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 105, 'point': -9.5},
#        {'name': 'Cleveland Browns', 'price': -125, 'point': 9.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 8.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -109, 'point': -9.0},
#        {'name': 'Cleveland Browns', 'price': -109, 'point': 9.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 8.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -109, 'point': -8.0},
#        {'name': 'Cleveland Browns', 'price': -109, 'point': 8.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -118, 'point': 8.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -105, 'point': -8.5},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 8.5}]}]}]},
#  {'id': 'b879f75b3c85ed1c8a686acaa9c03d9a',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New York Giants',
#   'away_team': 'Detroit Lions',
#   'bookmakers': [{'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -105, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -115, 'point': -3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -115, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -111, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -111, 'point': -3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -105, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -114, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -106, 'point': -3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -113, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -107, 'point': 3.5},
#        {'name': 'New York Giants', 'price': -107, 'point': -3.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -109, 'point': -3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -118, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.0},
#        {'name': 'New York Giants', 'price': -110, 'point': -3.0}]}]}]},
#  {'id': '13609957f97b2469d6a01db2ad42a053',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Houston Texans',
#   'away_team': 'Washington Commanders',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -115, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': 100, 'point': -3.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -113, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 105, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -116, 'point': -3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -120, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': -3.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -120, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -102, 'point': -3.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -113, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -113, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -105, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -113, 'point': -3.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -115, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -105, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -113, 'point': 3.5},
#        {'name': 'Washington Commanders', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 100, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': -110, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Houston Texans', 'price': 101, 'point': 3.0},
#        {'name': 'Washington Commanders', 'price': -119, 'point': -3.0}]}]}]},
#  {'id': '165cbe2f28ce9b22f4dda8169843f848',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'Indianapolis Colts',
#   'away_team': 'Philadelphia Eagles',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -107, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -107, 'point': -6.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -112, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -6.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -111, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -111, 'point': -6.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -105, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -105, 'point': -6.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -125, 'point': 7.0},
#        {'name': 'Philadelphia Eagles', 'price': 105, 'point': -7.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -112, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -6.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -112, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -6.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': 100, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -118, 'point': -6.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -112, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -6.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -105, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -115, 'point': -6.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -110, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -110, 'point': -6.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Indianapolis Colts', 'price': -109, 'point': 6.5},
#        {'name': 'Philadelphia Eagles', 'price': -109, 'point': -6.5}]}]}]},
#  {'id': '45a5068369254d1d6c1b925e3792068d',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New Orleans Saints',
#   'away_team': 'Los Angeles Rams',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -108, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -113, 'point': -4.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -106, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -115, 'point': -4.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -108, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -113, 'point': -4.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': 100, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -120, 'point': -4.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -108, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -113, 'point': -4.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -101, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -108, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -113, 'point': -4.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -105, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -115, 'point': -4.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -107, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -112, 'point': -4.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -107, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -107, 'point': -4.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -109, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': -4.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Rams', 'price': -110, 'point': 4.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': -4.0}]}]}]},
#  {'id': '52229c7e0378a451ccd345fe8de45a52',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-20T18:00:00Z',
#   'home_team': 'New England Patriots',
#   'away_team': 'New York Jets',
#   'bookmakers': [{'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -115,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -115,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -115,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -105, 'point': 3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -109, 'point': 3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -3.0},
#        {'name': 'New York Jets', 'price': -110, 'point': 3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -102,
#         'point': -3.5},
# ...
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 1.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -120, 'point': 0.0},
#        {'name': 'Minnesota Vikings', 'price': 100, 'point': 0.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 1.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': 1.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -105, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -105, 'point': 1.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': 106, 'point': -2.5},
#        {'name': 'Minnesota Vikings', 'price': -125, 'point': 2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -107, 'point': -1.5},
#        {'name': 'Minnesota Vikings', 'price': -107, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -109, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -109, 'point': 1.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Cowboys', 'price': -110, 'point': -1.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': 1.0}]}]}]},
#  {'id': 'bc7a7e572d3b7b9ed988a9feebf09aa6',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-21T01:20:00Z',
#   'home_team': 'Los Angeles Chargers',
#   'away_team': 'Kansas City Chiefs',
#   'bookmakers': [{'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -113,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -108, 'point': 6.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -120,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': 100, 'point': 6.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -116,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': 105, 'point': 6.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -112,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -107, 'point': 6.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -112,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -108, 'point': 6.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -110, 'point': 6.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs', 'price': 110, 'point': -7.5},
#        {'name': 'Los Angeles Chargers', 'price': -130, 'point': 7.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -113,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -108, 'point': 6.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -113,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -108, 'point': 6.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -107,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -107, 'point': 6.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -113,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -108, 'point': 6.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -109,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -109, 'point': 6.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -115,
#         'point': -6.5},
#        {'name': 'Los Angeles Chargers', 'price': -105, 'point': 6.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Chiefs',
#         'price': -105,
#         'point': -7.0},
#        {'name': 'Los Angeles Chargers', 'price': -115, 'point': 7.0}]}]}]},
#  {'id': '6cb8b70ef8969b46535e63a71e9500f5',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-22T01:15:00Z',
#   'home_team': 'Arizona Cardinals',
#   'away_team': 'San Francisco 49ers',
#   'bookmakers': [{'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-11-16T05:27:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-11-16T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-11-16T05:28:59Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -108, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -114, 'point': -8.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-11-16T05:25:49Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-11-16T05:25:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -102, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -108, 'point': -8.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-11-16T05:29:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -105, 'point': 7.5},
#        {'name': 'San Francisco 49ers', 'price': -113, 'point': -7.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-11-16T05:28:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-11-16T05:24:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-11-16T05:25:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-11-16T05:28:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-11-16T05:27:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -120, 'point': 9.5},
#        {'name': 'San Francisco 49ers', 'price': 100, 'point': -9.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-11-16T05:24:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-11-16T05:24:20Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-11-16T05:25:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -109, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -109, 'point': -8.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-11-16T05:24:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -105, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -115, 'point': -8.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-11-16T05:27:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-11-16T05:25:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -107, 'point': -8.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-11-16T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 8.0},
#        {'name': 'San Francisco 49ers', 'price': -110, 'point': -8.0}]}]}]}]

# %%
len(odds_json)
# Out:
# 14

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Green Bay Packers -3.0
# ----------------------
# Tennessee Titans 3.0
#
# ----------------------
# Atlanta Falcons -3.0
# ----------------------
# Chicago Bears 3.0
#
# ----------------------
# Baltimore Ravens -12.0
# ----------------------
# Carolina Panthers 12.0
#
# ----------------------
# Buffalo Bills -8.5
# ----------------------
# Cleveland Browns 8.5
#
# ----------------------
# Detroit Lions 3.0
# ----------------------
# New York Giants -3.0
#
# ----------------------
# Houston Texans 3.5
# ----------------------
# Washington Commanders -3.5
#
# ----------------------
# Indianapolis Colts 6.5
# ----------------------
# Philadelphia Eagles -6.5
#
# ----------------------
# Los Angeles Rams 4.0
# ----------------------
# New Orleans Saints -4.0
#
# ----------------------
# New England Patriots -3.0
# ----------------------
# New York Jets 3.0
#
# ----------------------
# Denver Broncos -2.5
# ----------------------
# Las Vegas Raiders 2.5
#
# ----------------------
# Cincinnati Bengals -5.0
# ----------------------
# Pittsburgh Steelers 5.0
#
# ----------------------
# Dallas Cowboys -1.0
# ----------------------
# Minnesota Vikings 1.0
#
# ----------------------
# Kansas City Chiefs -6.5
# ----------------------
# Los Angeles Chargers 6.5
#
# ----------------------
# Arizona Cardinals 8.0
# ----------------------
# San Francisco 49ers -8.0

# %%
print(odds_json[0]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# Green Bay Packers

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Green Bay Packers -3.0
# ----------------------
# Tennessee Titans 3.0
#
# ----------------------
# Atlanta Falcons -3.0
# ----------------------
# Chicago Bears 3.0
#
# ----------------------
# Baltimore Ravens -12.0
# ----------------------
# Carolina Panthers 12.0
#
# ----------------------
# Buffalo Bills -8.5
# ----------------------
# Cleveland Browns 8.5
#
# ----------------------
# Detroit Lions 3.0
# ----------------------
# New York Giants -3.0
#
# ----------------------
# Houston Texans 3.5
# ----------------------
# Washington Commanders -3.5
#
# ----------------------
# Indianapolis Colts 6.5
# ----------------------
# Philadelphia Eagles -6.5
#
# ----------------------
# Los Angeles Rams 4.0
# ----------------------
# New Orleans Saints -4.0
#
# ----------------------
# New England Patriots -3.0
# ----------------------
# New York Jets 3.0
#
# ----------------------
# Denver Broncos -2.5
# ----------------------
# Las Vegas Raiders 2.5
#
# ----------------------
# Cincinnati Bengals -5.0
# ----------------------
# Pittsburgh Steelers 5.0
#
# ----------------------
# Dallas Cowboys -1.0
# ----------------------
# Minnesota Vikings 1.0
#
# ----------------------
# Kansas City Chiefs -6.5
# ----------------------
# Los Angeles Chargers 6.5
#
# ----------------------
# Arizona Cardinals 8.0
# ----------------------
# San Francisco 49ers -8.0

# %%
print(odds_json[9]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# Denver Broncos

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# ['Green Bay Packers',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'New York Giants',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'New Orleans Saints',
#  'New England Patriots',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings',
#  'Los Angeles Chargers',
#  'Arizona Cardinals']

# %%
odds_json[0]["home_team"]
# Out:
# 'Green Bay Packers'

# %%
home_team_spread=[]

for x in range(len(odds_json)):
    home_spread = odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"]
    home_team_spread.append(home_spread)
                     
home_team_spread
# Out:
# [-3.0,
#  -3.0,
#  -12.0,
#  -8.5,
#  3.0,
#  3.5,
#  6.5,
#  4.0,
#  -3.0,
#  -2.5,
#  -5.0,
#  -1.0,
#  -6.5,
#  8.0]

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# ['Tennessee Titans',
#  'Chicago Bears',
#  'Carolina Panthers',
#  'Cleveland Browns',
#  'Detroit Lions',
#  'Washington Commanders',
#  'Philadelphia Eagles',
#  'Los Angeles Rams',
#  'New York Jets',
#  'Las Vegas Raiders',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Kansas City Chiefs',
#  'San Francisco 49ers']

# %%
away_team_spread=[]

for x in range(len(odds_json)):
    away_spread = odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"]
    away_team_spread.append(away_spread)
            
away_team_spread
# Out:
# [3.0, 3.0, 12.0, 8.5, -3.0, -3.5, -6.5, -4.0, 3.0, 2.5, 5.0, 1.0, 6.5, -8.0]

# %%
# # fave_team_spread=[]
# # sportsbook_list=[]

# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     if fave_spread not in fave_team_spread:
# #         fave_team_spread.append(fave_spread)
# #         sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     if dog_spread not in dog_team_spread:
# #         dog_team_spread.append(dog_spread)
# #         sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# # print(dog_team_spread)


# # fave_team_spread=[]
sportsbook_list=[]

# odds_json[0]["bookmakers"]
for x in range(len(odds_json[0]["bookmakers"])):
    sportsbook=odds_json[0]["bookmakers"][x]["title"]
    sportsbook_list.append(sportsbook)

print(sportsbook_list)
    
    




# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     fave_team_spread.append(fave_spread)
# #     sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     dog_team_spread.append(dog_spread)
# #     sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# print(dog_team_spread)
# Out:
# ['DraftKings', 'PointsBet (US)', 'BetUS', 'LowVig.ag', 'BetRivers', 'SugarHouse', 'FanDuel', 'BetOnline.ag', 'Barstool Sportsbook', 'William Hill (US)', 'SuperBook', 'Unibet', 'BetMGM', 'WynnBET', 'Circa Sports', 'MyBookie.ag', 'GTbets', 'FOX Bet', 'Intertops']

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Green Bay Packers',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'New York Giants',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'New Orleans Saints',
#  'New England Patriots',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings',
#  'Los Angeles Chargers',
#  'Arizona Cardinals']

# %%
len(home_team_spread)
# Out:
# 14

# %%
FD_Daily_Spread_Dict={"Home_Team":home_team_list, "Home Team Spread":home_team_spread,"Away_Team":away_team_list, "Away Team Spread":away_team_spread}
FD_Daily_Spread_Dict
# Out:
# {'Home_Team': ['Green Bay Packers',
#   'Atlanta Falcons',
#   'Baltimore Ravens',
#   'Buffalo Bills',
#   'New York Giants',
#   'Houston Texans',
#   'Indianapolis Colts',
#   'New Orleans Saints',
#   'New England Patriots',
#   'Denver Broncos',
#   'Pittsburgh Steelers',
#   'Minnesota Vikings',
#   'Los Angeles Chargers',
#   'Arizona Cardinals'],
#  'Home Team Spread': [-3.0,
#   -3.0,
#   -12.0,
#   -8.5,
#   3.0,
#   3.5,
#   6.5,
#   4.0,
#   -3.0,
#   -2.5,
#   -5.0,
#   -1.0,
#   -6.5,
#   8.0],
#  'Away_Team': ['Tennessee Titans',
#   'Chicago Bears',
#   'Carolina Panthers',
#   'Cleveland Browns',
#   'Detroit Lions',
#   'Washington Commanders',
#   'Philadelphia Eagles',
#   'Los Angeles Rams',
#   'New York Jets',
#   'Las Vegas Raiders',
#   'Cincinnati Bengals',
#   'Dallas Cowboys',
#   'Kansas City Chiefs',
#   'San Francisco 49ers'],
#  'Away Team Spread': [3.0,
#   3.0,
#   12.0,
#   8.5,
#   -3.0,
#   -3.5,
#   -6.5,
#   -4.0,
#   3.0,
#   2.5,
#   5.0,
#   1.0,
#   6.5,
#   -8.0]}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['DraftKings',
#  'PointsBet (US)',
#  'BetUS',
#  'LowVig.ag',
#  'BetRivers',
#  'SugarHouse',
#  'FanDuel',
#  'BetOnline.ag',
#  'Barstool Sportsbook',
#  'William Hill (US)',
#  'SuperBook',
#  'Unibet',
#  'BetMGM',
#  'WynnBET',
#  'Circa Sports',
#  'MyBookie.ag',
#  'GTbets',
#  'FOX Bet',
#  'Intertops']

# %%
# This layout is perfect for volume bettors who bet smaller units across multiple games

SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
#                Home_Team  Home Team Spread              Away_Team  \
# 0      Green Bay Packers              -3.0       Tennessee Titans
# 1        Atlanta Falcons              -3.0          Chicago Bears
# 2       Baltimore Ravens             -12.0      Carolina Panthers
# 3          Buffalo Bills              -8.5       Cleveland Browns
# 4        New York Giants               3.0          Detroit Lions
# 5         Houston Texans               3.5  Washington Commanders
# 6     Indianapolis Colts               6.5    Philadelphia Eagles
# 7     New Orleans Saints               4.0       Los Angeles Rams
# 8   New England Patriots              -3.0          New York Jets
# 9         Denver Broncos              -2.5      Las Vegas Raiders
# 10   Pittsburgh Steelers              -5.0     Cincinnati Bengals
# 11     Minnesota Vikings              -1.0         Dallas Cowboys
# 12  Los Angeles Chargers              -6.5     Kansas City Chiefs
# 13     Arizona Cardinals               8.0    San Francisco 49ers
#
#     Away Team Spread
# 0                3.0
# 1                3.0
# 2               12.0
# 3                8.5
# 4               -3.0
# 5               -3.5
# 6               -6.5
# 7               -4.0
# 8                3.0
# 9                2.5
# 10               5.0
# 11               1.0
# 12               6.5
# 13              -8.0

# %%
# Create the output file (CSV).
output_data_file = "NFL_Week11_Tuesday_Export.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
