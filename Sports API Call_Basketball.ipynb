# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'basketball_nba' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'cricket_ipl', 'group': 'Cricket', 'title': 'IPL', 'description': 'Indian Premier League', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_argentina_primera_division', 'group': 'Soccer', 'title': 'Primera División - Argentina', 'description': 'Argentine Primera División', 'active': True, 'has_outrights': False}, {'key': 'soccer_australia_aleague', 'group': 'Soccer', 'title': 'A-League', 'description': 'Aussie Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_belgium_first_div', 'group': 'Soccer', 'title': 'Belgium First Div', 'description': 'Belgian First Division A', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_campeonato', 'group': 'Soccer', 'title': 'Brazil Série A', 'description': 'Brasileirão Série A', 'active': True, 'has_outrights': False}, {'key': 'soccer_denmark_superliga', 'group': 'Soccer', 'title': 'Denmark Superliga', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_efl_champ', 'group': 'Soccer', 'title': 'Championship', 'description': 'EFL Championship', 'active': True, 'has_outrights': False}, {'key': 'soccer_england_league1', 'group': 'Soccer', 'title': 'League 1', 'description': 'EFL League 1', 'active': True, 'has_outrights ...
# Number of events: 4
# [{'id': '271cf1e73a4e2caa33331ef15ace8bc1', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2022-05-06T23:00:00Z', 'home_team': 'Philadelphia 76ers', 'away_team': 'Miami Heat', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-05-05T19:40:40Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2022-05-05T19:34:47Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -108, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -102, 'point': 1.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-05-05T19:41:11Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-05-05T19:38:15Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -105, 'point': -1.5}, {'name': 'Philadelphia 76ers', 'price': -115, 'point': 1.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-05-05T19:39:09Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2022-05-05T19:36:19Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2022-05-05T19:40:34Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -114, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -108, 'point': 1.0}]}]}, {'key': 'gtbets', 'title': 'GTbets', 'last_update': '2022-05-05T19:34:50Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -109, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -109, 'point': 1.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2022-05-05T19:40:18Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-05-05T19:38:08Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2022-05-05T19:36:19Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-05-05T19:40:56Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2022-05-05T19:41:10Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'unibet', 'title': 'Unibet', 'last_update': '2022-05-05T19:35:17Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-05-05T19:40:40Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0}, {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-05-05T19:40:33Z', 'markets': [{'key': 'spreads', ' ...
# Remaining requests 499
# Used requests 1

# %%
# odds_json

odds_json
# Out:
# [{'id': '271cf1e73a4e2caa33331ef15ace8bc1',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-05-06T23:00:00Z',
#   'home_team': 'Philadelphia 76ers',
#   'away_team': 'Miami Heat',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-05-05T19:34:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -108, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -102, 'point': 1.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-05-05T19:41:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-05-05T19:38:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -105, 'point': -1.5},
#        {'name': 'Philadelphia 76ers', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-05-05T19:39:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-05-05T19:40:34Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -114, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-05-05T19:34:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -109, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -109, 'point': 1.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-05-05T19:40:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-05-05T19:38:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.5},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-05-05T19:40:56Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-05-05T19:41:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-05-05T19:35:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-05-05T19:40:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-05-05T19:39:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -108, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-05-05T19:37:13Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -115, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -105, 'point': 1.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-05-05T19:34:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Heat', 'price': -110, 'point': -1.0},
#        {'name': 'Philadelphia 76ers', 'price': -110, 'point': 1.0}]}]}]},
#  {'id': 'd8d28fc107a97cf563a2afa3307c2f24',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-05-07T01:30:00Z',
#   'home_team': 'Dallas Mavericks',
#   'away_team': 'Phoenix Suns',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -118, 'point': 1.0},
#        {'name': 'Phoenix Suns', 'price': -104, 'point': -1.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-05-05T19:41:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -115, 'point': 1.0},
#        {'name': 'Phoenix Suns', 'price': -105, 'point': -1.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -118, 'point': 1.0},
#        {'name': 'Phoenix Suns', 'price': 100, 'point': -1.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-05-05T19:38:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -120, 'point': 1.5},
#        {'name': 'Phoenix Suns', 'price': 100, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-05-05T19:40:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -106, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-05-05T19:34:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -105, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -105, 'point': 0.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-05-05T19:40:56Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -106, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-05-05T19:41:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -106, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-05-05T19:35:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -105, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -106, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-05-05T19:40:34Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -111, 'point': -0.0},
#        {'name': 'Phoenix Suns', 'price': -111, 'point': 0.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-05-05T19:39:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -110, 'point': -0.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-05-05T19:39:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -108, 'point': 1.0},
#        {'name': 'Phoenix Suns', 'price': -108, 'point': -1.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-05-05T19:38:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -105, 'point': -1.0},
#        {'name': 'Phoenix Suns', 'price': -115, 'point': 1.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-05-05T19:40:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -110, 'point': 0.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-05-05T19:34:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -109, 'point': 0.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -110, 'point': 0.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-05-05T19:34:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 0.0},
#        {'name': 'Phoenix Suns', 'price': -110, 'point': 0.0}]}]}]},
#  {'id': '2d4450b5736fe68bca01cc7a5bb5a0ca',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-05-07T19:30:00Z',
#   'home_team': 'Milwaukee Bucks',
#   'away_team': 'Boston Celtics',
#   'bookmakers': [{'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-05-05T19:39:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -108, 'point': 2.5},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -2.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-05-05T19:41:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -115, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-05-05T19:39:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-05-05T19:40:34Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -115, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-05-05T19:34:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': 100, 'point': -3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 2.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-05-05T19:38:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-05-05T19:38:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 2.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-05-05T19:34:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -109, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -109, 'point': -3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-05-05T19:37:13Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -113, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-05-05T19:41:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -113, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-05-05T19:40:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -113, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-05-05T19:40:56Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -113, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-05-05T19:35:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -112, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-05-05T19:40:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-05-05T19:34:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Celtics', 'price': -110, 'point': 3.0},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -3.0}]}]}]},
#  {'id': '57eb4b24d006aa8cc792a3ab3c87a8d1',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-05-08T00:30:00Z',
#   'home_team': 'Golden State Warriors',
#   'away_team': 'Memphis Grizzlies',
#   'bookmakers': [{'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-05-05T19:41:11Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-05-05T19:39:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -108,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -108, 'point': 7.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-05-05T19:38:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -115,
#         'point': -6.5},
#        {'name': 'Memphis Grizzlies', 'price': -105, 'point': 6.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-05-05T19:38:08Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-05-05T19:34:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -105,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -105, 'point': 7.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-05-05T19:39:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-05-05T19:40:34Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -111,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -111, 'point': 7.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-05-05T19:35:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-05-05T19:34:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -109,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -109, 'point': 7.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-05-05T19:40:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-05-05T19:40:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-05-05T19:41:10Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-05-05T19:40:56Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-05-05T19:37:13Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-05-05T19:40:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -115,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -105, 'point': 7.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-05-05T19:36:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -7.0},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 7.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-05-05T19:34:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Golden State Warriors',
#         'price': -110,
#         'point': -6.5},
#        {'name': 'Memphis Grizzlies', 'price': -110, 'point': 6.5}]}]}]}]

# %%
len(odds_json)
# Out:
# 4

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["home_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("----------------------")
    print(odds_json[x]["away_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Philadelphia 76ers 1.0
# ----------------------
# Miami Heat -1.0
#
# ----------------------
# Dallas Mavericks -1.0
# ----------------------
# Phoenix Suns 1.0
#
# ----------------------
# Milwaukee Bucks -2.5
# ----------------------
# Boston Celtics 2.5
#
# ----------------------
# Golden State Warriors 7.0
# ----------------------
# Memphis Grizzlies -7.0

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# ['Philadelphia 76ers',
#  'Dallas Mavericks',
#  'Milwaukee Bucks',
#  'Golden State Warriors']

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# ['Miami Heat', 'Phoenix Suns', 'Boston Celtics', 'Memphis Grizzlies']

# %%
# fave_team_spread=[]
# sportsbook_list=[]

# for x in range(len(odds_json)):
#     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
#     sportsbook= odds_json[x]["bookmakers"][x]['title']
#     if fave_spread not in fave_team_spread:
#         fave_team_spread.append(fave_spread)
#         sportsbook_list.append(sportsbook)
            
            
            

# fave_team_spread



# sportsbook_list2=[]
# dog_team_spread=[]

# for x in range(len(odds_json)):
#     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
#     sportsbook2= odds_json[x]["bookmakers"][x]['title']

#     if dog_spread not in dog_team_spread:
#         dog_team_spread.append(dog_spread)
#         sportsbook_list2.append(sportsbook2)

            
            

# dog_team_spread

# print(fave_team_spread)
# print(dog_team_spread)



fave_team_spread=[]
sportsbook_list=[]

for x in range(len(odds_json)):
    fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
    sportsbook= odds_json[x]["bookmakers"][x]['title']
    fave_team_spread.append(fave_spread)
    sportsbook_list.append(sportsbook)
            
            
            

fave_team_spread



sportsbook_list2=[]
dog_team_spread=[]

for x in range(len(odds_json)):
    dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
    sportsbook2= odds_json[x]["bookmakers"][x]['title']

    dog_team_spread.append(dog_spread)
    sportsbook_list2.append(sportsbook2)

            
            

dog_team_spread

print(fave_team_spread)
print(dog_team_spread)
# Out:
# [-1.0, 1.0, 3.0, -7.0]
# [1.0, -1.0, -3.0, 7.0]

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Philadelphia 76ers',
#  'Dallas Mavericks',
#  'Milwaukee Bucks',
#  'Golden State Warriors']

# %%
FD_Daily_Spread_Dict={"Best Sports Book(HT)":sportsbook_list,"Home_Team":home_team_list, "Favored Team Spread":fave_team_spread,"Best Sports Book(HT)":sportsbook_list2, "Away_Team":away_team_list, "Underdog Team Spread":dog_team_spread, "Home Arena Belongs To":competition_site}
FD_Daily_Spread_Dict
# Out:
# {'Best Sports Book(HT)': ['FanDuel',
#   'DraftKings',
#   'William Hill (US)',
#   'WynnBET'],
#  'Home_Team': ['Philadelphia 76ers',
#   'Dallas Mavericks',
#   'Milwaukee Bucks',
#   'Golden State Warriors'],
#  'Favored Team Spread': [-1.0, 1.0, 3.0, -7.0],
#  'Away_Team': ['Miami Heat',
#   'Phoenix Suns',
#   'Boston Celtics',
#   'Memphis Grizzlies'],
#  'Underdog Team Spread': [1.0, -1.0, -3.0, 7.0],
#  'Home Arena Belongs To': ['Philadelphia 76ers',
#   'Dallas Mavericks',
#   'Milwaukee Bucks',
#   'Golden State Warriors']}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['FanDuel',
#  'LowVig.ag',
#  'DraftKings',
#  'BetMGM',
#  'William Hill (US)',
#  'FOX Bet',
#  'BetOnline.ag',
#  'GTbets',
#  'Bovada',
#  'PointsBet (US)',
#  'BetUS',
#  'SugarHouse',
#  'TwinSpires',
#  'Unibet',
#  'Barstool Sportsbook',
#  'BetRivers',
#  'WynnBET',
#  'Intertops',
#  'MyBookie.ag']

# %%
# This layout is perfect for volume bettors who bet smaller units across multiple games

SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
#   Best Sports Book(HT)              Home_Team  Favored Team Spread  \
# 0              FanDuel     Philadelphia 76ers                 -1.0
# 1           DraftKings       Dallas Mavericks                  1.0
# 2    William Hill (US)        Milwaukee Bucks                  3.0
# 3              WynnBET  Golden State Warriors                 -7.0
#
#            Away_Team  Underdog Team Spread  Home Arena Belongs To
# 0         Miami Heat                   1.0     Philadelphia 76ers
# 1       Phoenix Suns                  -1.0       Dallas Mavericks
# 2     Boston Celtics                  -3.0        Milwaukee Bucks
# 3  Memphis Grizzlies                   7.0  Golden State Warriors

# %%
# Create the output file (CSV).
output_data_file = "NBA_Basketball_4.5.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
