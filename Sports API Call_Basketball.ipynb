# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'basketball_nba' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'cricket_ipl', 'group': 'Cricket', 'title': 'IPL', 'description': 'Indian Premier League', 'active': True, 'has_outrights': False}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_argentina_primera_division', 'group': 'Soccer', 'title': 'Primera División - Argentina', 'description': 'Argentine Primera División', 'active': True, 'has_outrights': False}, {'key': 'soccer_australia_aleague', 'group': 'Soccer', 'title': 'A-League', 'description': 'Aussie Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_campeonato', 'group': 'Soccer', 'title': 'Brazil Série A', 'description': 'Brasileirão Série A', 'active': True, 'has_outrights': False}, {'key': 'soccer_denmark_superliga', 'group': 'Soccer', 'title': 'Denmark Superliga', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_efl_champ', 'group': 'Soccer', 'title': 'Championship', 'description': 'EFL Championship', 'active': True, 'has_outrights': False}, {'key': 'soccer_england_league1', 'group': 'Soccer', 'title': 'League 1', 'description': 'EFL League 1', 'active': True, 'has_outrights': False}, {'key': 'soccer_england_league2', 'group': 'Soccer', 'title': 'League 2', 'description': 'EFL League 2 ', 'active': Tr ...
# Number of events: 9
# [{'id': '8ac0d0aebf3937646ecc738e0aec3c8d', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2022-04-12T23:00:00Z', 'home_team': 'Brooklyn Nets', 'away_team': 'Cleveland Cavaliers', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-04-12T05:28:00Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-04-12T05:26:24Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-04-12T05:26:06Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2022-04-12T05:22:39Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -116, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': 105, 'point': 8.5}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2022-04-12T05:27:00Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -120, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': 100, 'point': 8.5}]}]}, {'key': 'unibet', 'title': 'Unibet', 'last_update': '2022-04-12T05:25:39Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-04-12T05:25:47Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-04-12T05:27:40Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-04-12T05:27:28Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2022-04-12T05:27:52Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2022-04-12T05:23:54Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2022-04-12T05:25:39Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-04-12T05:23:58Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2022-04-12T05:22:40Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-04-12T05:26:19Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Brooklyn Nets', 'price': -108, 'point': -8.5}, {'name': 'Cleveland Cavaliers', 'price': -108, 'point': 8.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_u ...
# Remaining requests 496
# Used requests 4

# %%
# odds_json

odds_json
# Out:
# [{'id': '8ac0d0aebf3937646ecc738e0aec3c8d',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-12T23:00:00Z',
#   'home_team': 'Brooklyn Nets',
#   'away_team': 'Cleveland Cavaliers',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -116, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': 105, 'point': 8.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -120, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': 100, 'point': 8.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -108, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -108, 'point': 8.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -109, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -109, 'point': 8.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Brooklyn Nets', 'price': -110, 'point': -8.5},
#        {'name': 'Cleveland Cavaliers', 'price': -110, 'point': 8.5}]}]}]},
#  {'id': 'b25c3cced79b04d80685f9cd9bc57f11',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-13T01:30:00Z',
#   'home_team': 'Minnesota Timberwolves',
#   'away_team': 'Los Angeles Clippers',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -115,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -105, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -105,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -115, 'point': -3.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': 100,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -108,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -108, 'point': -3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -111, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -109,
#         'point': 3.0},
#        {'name': 'Minnesota Timberwolves', 'price': -109, 'point': -3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Clippers',
#         'price': -110,
#         'point': 3.5},
#        {'name': 'Minnesota Timberwolves', 'price': -110, 'point': -3.5}]}]}]},
#  {'id': 'b2030f52d6bb26e4b6b61b928330c311',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-13T23:00:00Z',
#   'home_team': 'Atlanta Hawks',
#   'away_team': 'Charlotte Hornets',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -106, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': 100, 'point': 4.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -115, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -105, 'point': 4.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -106, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -107, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -107, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -107, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -107, 'point': -5.0},
#        {'name': 'Charlotte Hornets', 'price': -114, 'point': 5.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -118, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': 100, 'point': 4.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -108, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -108, 'point': 4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -110, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -109, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -109, 'point': 4.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Hawks', 'price': -115, 'point': -4.5},
#        {'name': 'Charlotte Hornets', 'price': -105, 'point': 4.5}]}]}]},
#  {'id': 'e140e434facd8456625b269e3bb99ebd',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-14T01:30:00Z',
#   'home_team': 'New Orleans Pelicans',
#   'away_team': 'San Antonio Spurs',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -111,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -111, 'point': 5.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -105,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -105, 'point': 5.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -108,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -108, 'point': 5.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -118,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': 100, 'point': 5.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.5},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -109,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -109, 'point': 5.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New Orleans Pelicans',
#         'price': -110,
#         'point': -5.0},
#        {'name': 'San Antonio Spurs', 'price': -110, 'point': 5.0}]}]}]},
#  {'id': '4d9d3ef86cfc82a4867ee33aabfc68f5',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-16T17:00:00Z',
#   'home_team': 'Dallas Mavericks',
#   'away_team': 'Utah Jazz',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -108, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -105, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -115, 'point': -3.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -111, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -109, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -109, 'point': -3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': 105, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -116, 'point': -3.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': 100, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -120, 'point': -3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': 105, 'point': 2.5},
#        {'name': 'Utah Jazz', 'price': -125, 'point': -2.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -105, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -115, 'point': -3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -108, 'point': 3.5},
#        {'name': 'Utah Jazz', 'price': -108, 'point': -3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Dallas Mavericks', 'price': -110, 'point': 3.0},
#        {'name': 'Utah Jazz', 'price': -110, 'point': -3.0}]}]}]},
#  {'id': 'ea05ba0c66880594fc2fe07497889f93',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-16T22:00:00Z',
#   'home_team': 'Philadelphia 76ers',
#   'away_team': 'Toronto Raptors',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -115,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -105, 'point': 4.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -113,
#         'point': -4.0},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -113,
#         'point': -4.0},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.0}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -112,
#         'point': -4.0},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -113,
#         'point': -4.0},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -113,
#         'point': -4.0},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -109,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -109, 'point': 4.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -105,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -105, 'point': 4.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -111,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -111, 'point': 4.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -108,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -108, 'point': 4.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers',
#         'price': -110,
#         'point': -4.5},
#        {'name': 'Toronto Raptors', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia 76ers', 'price': 100, 'point': -5.0},
#        {'name': 'Toronto Raptors', 'price': -118, 'point': 5.0}]}]}]},
#  {'id': 'd3d7f848492b501db285bfd0d909b827',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-17T00:30:00Z',
#   'home_team': 'Golden State Warriors',
#   'away_team': 'Denver Nuggets',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -108, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -112, 'point': -4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-12T05:26:16Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -115, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -105, 'point': -4.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -115, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -105, 'point': -4.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -112, 'point': -4.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -112, 'point': -4.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -111, 'point': -4.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -112, 'point': -4.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -112, 'point': -4.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -109, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -109, 'point': -4.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -115, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -105, 'point': -4.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': 100, 'point': -4.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -108, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -108, 'point': -4.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -110, 'point': 4.5},
#        {'name': 'Golden State Warriors', 'price': -110, 'point': -4.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-04-12T05:23:54Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Nuggets', 'price': -118, 'point': 5.0},
#        {'name': 'Golden State Warriors', 'price': 100, 'point': -5.0}]}]}]},
#  {'id': '4aa919d9d10d73ab59f145c35afbf782',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-17T17:00:00Z',
#   'home_team': 'Milwaukee Bucks',
#   'away_team': 'Chicago Bulls',
#   'bookmakers': [{'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-04-12T05:25:47Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-04-12T05:27:52Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-04-12T05:27:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-04-12T05:27:28Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-04-12T05:26:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-04-12T05:22:40Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -105, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -115, 'point': -9.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-04-12T05:27:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -105, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -115, 'point': -9.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-04-12T05:22:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -101, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-04-12T05:23:58Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -105, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -115, 'point': -9.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-04-12T05:25:39Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-04-12T05:27:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-12T05:23:04Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]}]},
#  {'id': 'dd8cb181a6996b134c94d3fe2e5d6544',
#   'sport_key': 'basketball_nba',
#   'sport_title': 'NBA',
#   'commence_time': '2022-04-18T02:00:00Z',
#   'home_team': 'Milwaukee Bucks',
#   'away_team': 'Chicago Bulls',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-12T05:28:00Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-12T05:26:06Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -110, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-12T05:23:03Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -109, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-04-12T05:26:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bulls', 'price': -108, 'point': 9.5},
#        {'name': 'Milwaukee Bucks', 'price': -108, 'point': -9.5}]}]}]}]

# %%
len(odds_json)
# Out:
# 9

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)-1):
    print("----------------------")
    print(odds_json[x]["home_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("----------------------")
    print(odds_json[x]["away_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Brooklyn Nets 8.5
# ----------------------
# Cleveland Cavaliers -8.5
#
# ----------------------
# Minnesota Timberwolves -3.0
# ----------------------
# Los Angeles Clippers 3.0
#
# ----------------------
# Atlanta Hawks 5.0
# ----------------------
# Charlotte Hornets -5.0
#
# ----------------------
# New Orleans Pelicans 5.0
# ----------------------
# San Antonio Spurs -5.0
#
# ----------------------
# Dallas Mavericks -3.0
# ----------------------
# Utah Jazz 3.0
#
# ----------------------
# Philadelphia 76ers 4.5
# ----------------------
# Toronto Raptors -4.5
#
# ----------------------
# Golden State Warriors -4.5
# ----------------------
# Denver Nuggets 4.5
#
# ----------------------
# Milwaukee Bucks -9.5
# ----------------------
# Chicago Bulls 9.5

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)-1):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# ['Brooklyn Nets',
#  'Minnesota Timberwolves',
#  'Atlanta Hawks',
#  'New Orleans Pelicans',
#  'Dallas Mavericks',
#  'Philadelphia 76ers',
#  'Golden State Warriors',
#  'Milwaukee Bucks']

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)-1):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# ['Cleveland Cavaliers',
#  'Los Angeles Clippers',
#  'Charlotte Hornets',
#  'San Antonio Spurs',
#  'Utah Jazz',
#  'Toronto Raptors',
#  'Denver Nuggets',
#  'Chicago Bulls']

# %%
# fave_team_spread=[]
# sportsbook_list=[]

# for x in range(len(odds_json)):
#     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
#     sportsbook= odds_json[x]["bookmakers"][x]['title']
#     if fave_spread not in fave_team_spread:
#         fave_team_spread.append(fave_spread)
#         sportsbook_list.append(sportsbook)
            
            
            

# fave_team_spread



# sportsbook_list2=[]
# dog_team_spread=[]

# for x in range(len(odds_json)):
#     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
#     sportsbook2= odds_json[x]["bookmakers"][x]['title']

#     if dog_spread not in dog_team_spread:
#         dog_team_spread.append(dog_spread)
#         sportsbook_list2.append(sportsbook2)

            
            

# dog_team_spread

# print(fave_team_spread)
# print(dog_team_spread)



fave_team_spread=[]
sportsbook_list=[]

for x in range(len(odds_json)-1):
    fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
    sportsbook= odds_json[x]["bookmakers"][x]['title']
    fave_team_spread.append(fave_spread)
    sportsbook_list.append(sportsbook)
            
            
            

fave_team_spread



sportsbook_list2=[]
dog_team_spread=[]

for x in range(len(odds_json)-1):
    dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
    sportsbook2= odds_json[x]["bookmakers"][x]['title']

    dog_team_spread.append(dog_spread)
    sportsbook_list2.append(sportsbook2)

            
            

dog_team_spread

print(fave_team_spread)
print(dog_team_spread)
# Out:
# [-8.5, 3.0, -4.5, -5.0, 3.5, -4.0, 4.5, 9.5]
# [8.5, -3.0, 4.5, 5.0, -3.5, 4.0, -4.5, -9.5]

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Brooklyn Nets',
#  'Minnesota Timberwolves',
#  'Atlanta Hawks',
#  'New Orleans Pelicans',
#  'Dallas Mavericks',
#  'Philadelphia 76ers',
#  'Golden State Warriors',
#  'Milwaukee Bucks']

# %%
FD_Daily_Spread_Dict={"Best Sports Book(HT)":sportsbook_list,"Home_Team":home_team_list, "Favored Team Spread":fave_team_spread,"Best Sports Book(HT)":sportsbook_list2, "Away_Team":away_team_list, "Underdog Team Spread":dog_team_spread, "Home Arena Belongs To":competition_site}
FD_Daily_Spread_Dict
# Out:
# {'Best Sports Book(HT)': ['FanDuel',
#   'FanDuel',
#   'LowVig.ag',
#   'William Hill (US)',
#   'Barstool Sportsbook',
#   'Unibet',
#   'BetRivers',
#   'BetOnline.ag'],
#  'Home_Team': ['Brooklyn Nets',
#   'Minnesota Timberwolves',
#   'Atlanta Hawks',
#   'New Orleans Pelicans',
#   'Dallas Mavericks',
#   'Philadelphia 76ers',
#   'Golden State Warriors',
#   'Milwaukee Bucks'],
#  'Favored Team Spread': [-8.5, 3.0, -4.5, -5.0, 3.5, -4.0, 4.5, 9.5],
#  'Away_Team': ['Cleveland Cavaliers',
#   'Los Angeles Clippers',
#   'Charlotte Hornets',
#   'San Antonio Spurs',
#   'Utah Jazz',
#   'Toronto Raptors',
#   'Denver Nuggets',
#   'Chicago Bulls'],
#  'Underdog Team Spread': [8.5, -3.0, 4.5, 5.0, -3.5, 4.0, -4.5, -9.5],
#  'Home Arena Belongs To': ['Brooklyn Nets',
#   'Minnesota Timberwolves',
#   'Atlanta Hawks',
#   'New Orleans Pelicans',
#   'Dallas Mavericks',
#   'Philadelphia 76ers',
#   'Golden State Warriors',
#   'Milwaukee Bucks']}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['FanDuel',
#  'DraftKings',
#  'William Hill (US)',
#  'LowVig.ag',
#  'BetOnline.ag',
#  'Unibet',
#  'BetRivers',
#  'SugarHouse',
#  'Barstool Sportsbook',
#  'TwinSpires',
#  'FOX Bet',
#  'BetUS',
#  'BetMGM',
#  'Bovada',
#  'WynnBET',
#  'PointsBet (US)',
#  'MyBookie.ag',
#  'GTbets',
#  'Intertops']

# %%
SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
#   Best Sports Book(HT)               Home_Team  Favored Team Spread  \
# 0              FanDuel           Brooklyn Nets                 -8.5
# 1              FanDuel  Minnesota Timberwolves                  3.0
# 2            LowVig.ag           Atlanta Hawks                 -4.5
# 3    William Hill (US)    New Orleans Pelicans                 -5.0
# 4  Barstool Sportsbook        Dallas Mavericks                  3.5
# 5               Unibet      Philadelphia 76ers                 -4.0
# 6            BetRivers   Golden State Warriors                  4.5
# 7         BetOnline.ag         Milwaukee Bucks                  9.5
#
#               Away_Team  Underdog Team Spread   Home Arena Belongs To
# 0   Cleveland Cavaliers                   8.5           Brooklyn Nets
# 1  Los Angeles Clippers                  -3.0  Minnesota Timberwolves
# 2     Charlotte Hornets                   4.5           Atlanta Hawks
# 3     San Antonio Spurs                   5.0    New Orleans Pelicans
# 4             Utah Jazz                  -3.5        Dallas Mavericks
# 5       Toronto Raptors                   4.0      Philadelphia 76ers
# 6        Denver Nuggets                  -4.5   Golden State Warriors
# 7         Chicago Bulls                  -9.5         Milwaukee Bucks

# %%
# Create the output file (CSV).
output_data_file = "NBA_Basketball_4.5.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
