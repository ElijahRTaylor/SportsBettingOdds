# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'baseball_mlb' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'cricket_ipl', 'group': 'Cricket', 'title': 'IPL', 'description': 'Indian Premier League', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_argentina_primera_division', 'group': 'Soccer', 'title': 'Primera División - Argentina', 'description': 'Argentine Primera División', 'active': True, 'has_outrights': False}, {'key': 'soccer_australia_aleague', 'group': 'Soccer', 'title': 'A-League', 'description': 'Aussie Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_belgium_first_div', 'group': 'Soccer', 'title': 'Belgium First Div', 'description': 'Belgian First Division A', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_campeonato', 'group': 'Soccer', 'title': 'Brazil Série A', 'description': 'Brasileirão Série A', 'active': True, 'has_outrights': False}, {'key': 'soccer_denmark_superliga', 'group': 'Soccer', 'title': 'Denmark Superliga', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_efl_champ', 'group': 'Soccer', 'title': 'Championship', 'des ...
# Number of events: 15
# [{'id': '323d2f08d55717a10b13fc1b509576ec', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-04-05T19:05:00Z', 'home_team': 'Texas Rangers', 'away_team': 'Chicago Cubs', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-04-05T17:21:36Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5}, {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-04-05T17:21:33Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5}, {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]}, {'key': 'gtbets', 'title': 'GTbets', 'last_update': '2022-04-05T17:21:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5}, {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-04-05T17:21:02Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5}, {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]}]}, {'id': 'ca8cce61dafc7b61f27cd38a90c31533', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-04-05T19:05:00Z', 'home_team': 'Cincinnati Reds', 'away_team': 'Seattle Mariners', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-04-05T17:21:36Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5}, {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-04-05T17:21:33Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5}, {'name': 'Seattle Mariners', 'price': 140, 'point': -1.5}]}]}, {'key': 'gtbets', 'title': 'GTbets', 'last_update': '2022-04-05T17:21:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5}, {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-04-05T17:21:02Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5}, {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]}]}, {'id': '4d8b4a9041b2ce674ca63f6d4432c07c', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-04-05T19:10:00Z', 'home_team': 'San Diego Padres', 'away_team': 'Chicago White Sox', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-04-05T17:21:36Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago White Sox', 'price': -186, 'point': 1.5}, {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-04-05T17:21:33Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago White Sox', 'price': -175, 'point': 1.5}, {'name': 'San Diego Padres', 'price': 150, 'point': -1.5}]}]}, {'key': 'gtbets', 'title': 'GTbets', 'last_update': '2022-04-05T17:21:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago White Sox', 'price': -185, 'point': 1.5}, {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-04-05T17:21:02Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Chicago White Sox', 'price': -185, 'point': 1.5}, {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]}]}, {'id': '34018808bd9835725111fc6100a72935', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-04-05T19:10:00Z', 'home_team': 'Milwaukee Brewers', 'away_team': 'Kansas City Royals', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-04-05T17:21:36Z', 'markets': [{'key': 'spreads', 'outcomes': [{ ...
# Remaining requests 498
# Used requests 2

# %%
# odds_json

odds_json
# Out:
# [{'id': '323d2f08d55717a10b13fc1b509576ec',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-05T19:05:00Z',
#   'home_team': 'Texas Rangers',
#   'away_team': 'Chicago Cubs',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5},
#        {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5},
#        {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5},
#        {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -145, 'point': 1.5},
#        {'name': 'Texas Rangers', 'price': 125, 'point': -1.5}]}]}]},
#  {'id': 'ca8cce61dafc7b61f27cd38a90c31533',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-05T19:05:00Z',
#   'home_team': 'Cincinnati Reds',
#   'away_team': 'Seattle Mariners',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5},
#        {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5},
#        {'name': 'Seattle Mariners', 'price': 140, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5},
#        {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -160, 'point': 1.5},
#        {'name': 'Seattle Mariners', 'price': 135, 'point': -1.5}]}]}]},
#  {'id': '4d8b4a9041b2ce674ca63f6d4432c07c',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-05T19:10:00Z',
#   'home_team': 'San Diego Padres',
#   'away_team': 'Chicago White Sox',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': -186, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': -175, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': -185, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': -185, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': 155, 'point': -1.5}]}]}]},
#  {'id': '34018808bd9835725111fc6100a72935',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-05T19:10:00Z',
#   'home_team': 'Milwaukee Brewers',
#   'away_team': 'Kansas City Royals',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': -180, 'point': 1.5},
#        {'name': 'Milwaukee Brewers', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': -175, 'point': 1.5},
#        {'name': 'Milwaukee Brewers', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': -180, 'point': 1.5},
#        {'name': 'Milwaukee Brewers', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Kansas City Royals', 'price': -165, 'point': 1.5},
#        {'name': 'Milwaukee Brewers', 'price': 140, 'point': -1.5}]}]}]},
#  {'id': '38aa22c1d9c1819765be132f5e354c12',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-05T20:05:00Z',
#   'home_team': 'San Francisco Giants',
#   'away_team': 'Oakland Athletics',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Oakland Athletics', 'price': -136, 'point': 1.5},
#        {'name': 'San Francisco Giants', 'price': 115, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Oakland Athletics', 'price': -135, 'point': 1.5},
#        {'name': 'San Francisco Giants', 'price': 115, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Oakland Athletics', 'price': -135, 'point': 1.5},
#        {'name': 'San Francisco Giants', 'price': 115, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Oakland Athletics', 'price': -135, 'point': 1.5},
#        {'name': 'San Francisco Giants', 'price': 115, 'point': -1.5}]}]}]},
#  {'id': '9c7f5b1509b676cc3973e8297897b7b4',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-06T01:10:00Z',
#   'home_team': 'Los Angeles Dodgers',
#   'away_team': 'Los Angeles Angels',
#   'bookmakers': [{'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-04-05T17:21:33Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Angels', 'price': -130, 'point': 1.5},
#        {'name': 'Los Angeles Dodgers', 'price': 110, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-04-05T17:21:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Angels', 'price': -131, 'point': 1.5},
#        {'name': 'Los Angeles Dodgers', 'price': 110, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-04-05T17:21:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Angels', 'price': -130, 'point': 1.5},
#        {'name': 'Los Angeles Dodgers', 'price': 110, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-04-05T17:21:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Angels', 'price': -130, 'point': 1.5},
#        {'name': 'Los Angeles Dodgers', 'price': 110, 'point': -1.5}]}]}]},
#  {'id': '4b217f441008d90933a7cd174c90e934',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-07T17:06:00Z',
#   'home_team': 'New York Yankees',
#   'away_team': 'Boston Red Sox',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-04-05T17:21:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -160, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': 132, 'point': -1.5}]}]}]},
#  {'id': 'abdcd47cac870b5a97e9035dde0e097b',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-07T18:21:00Z',
#   'home_team': 'Chicago Cubs',
#   'away_team': 'Milwaukee Brewers',
#   'bookmakers': []},
#  {'id': 'c36929c71edb1793278df07346567743',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-07T20:11:00Z',
#   'home_team': 'Kansas City Royals',
#   'away_team': 'Cleveland Guardians',
#   'bookmakers': []},
#  {'id': '31542f2dbd2223fe09a51c10013e09f1',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-07T20:11:00Z',
#   'home_team': 'Minnesota Twins',
#   'away_team': 'Seattle Mariners',
#   'bookmakers': []},
#  {'id': '5491f3450ed7911ae420920ca5f9a5ce',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-07T20:16:00Z',
#   'home_team': 'St. Louis Cardinals',
#   'away_team': 'Pittsburgh Pirates',
#   'bookmakers': []},
#  {'id': '0bbf7662fd8db86e6d31bce8a9a5f5d2',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-08T00:09:00Z',
#   'home_team': 'Atlanta Braves',
#   'away_team': 'Cincinnati Reds',
#   'bookmakers': []},
#  {'id': 'afe2ad35e77a3b96536bc4486534061a',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-08T01:39:00Z',
#   'home_team': 'Los Angeles Angels',
#   'away_team': 'Houston Astros',
#   'bookmakers': []},
#  {'id': 'e1d25e1673c28d40155757e05b15407e',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-08T01:41:00Z',
#   'home_team': 'Arizona Diamondbacks',
#   'away_team': 'San Diego Padres',
#   'bookmakers': []},
#  {'id': '1d0c70b77e2c0e283be748e777f6e42f',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-04-08T23:08:00Z',
#   'home_team': 'Toronto Blue Jays',
#   'away_team': 'Texas Rangers',
#   'bookmakers': []}]

# %%
len(odds_json)
# Out:
# 15

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["home_team"],odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"])
    print("----------------------")
    print(odds_json[x]["away_team"],odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Texas Rangers -1.5
# ----------------------
# Chicago Cubs 1.5
#
# ----------------------
# Cincinnati Reds -1.5
# ----------------------
# Seattle Mariners 1.5
#
# ----------------------
# San Diego Padres -1.5
# ----------------------
# Chicago White Sox 1.5
#
# ----------------------
# Milwaukee Brewers -1.5
# ----------------------
# Kansas City Royals 1.5
#
# ----------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_5375/2913107167.py in <module>
#       4 for x in range(len(odds_json)):
#       5     print("----------------------")
# ----> 6     print(odds_json[x]["home_team"],odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"])
#       7     print("----------------------")
#       8     print(odds_json[x]["away_team"],odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"])
#
# IndexError: list index out of range

# %%
favorite_team_list=[]

for x in range(len(odds_json)):
    favored_team = (odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]['name'])
    if favored_team not in favorite_team_list:
                 favorite_team_list.append(favored_team)
                     
favorite_team_list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_5375/4252045428.py in <module>
#       2
#       3 for x in range(len(odds_json)):
# ----> 4     favored_team = (odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]['name'])
#       5     if favored_team not in favorite_team_list:
#       6                  favorite_team_list.append(favored_team)
#
# IndexError: list index out of range

# %%
dog_team_list=[]


for x in range(len(odds_json)):
    dog_team = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]['name']

    if dog_team not in dog_team_list:
                 dog_team_list.append(dog_team)
                     
dog_team_list
# Out:
# ['Orlando Magic',
#  'Philadelphia 76ers',
#  'Toronto Raptors',
#  'Houston Rockets',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Washington Wizards',
#  'Portland Trail Blazers',
#  'San Antonio Spurs',
#  'Utah Jazz',
#  'Sacramento Kings',
#  'Phoenix Suns']

# %%
# fave_team_spread=[]
# sportsbook_list=[]

# for x in range(len(odds_json)):
#     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
#     sportsbook= odds_json[x]["bookmakers"][x]['title']
#     if fave_spread not in fave_team_spread:
#         fave_team_spread.append(fave_spread)
#         sportsbook_list.append(sportsbook)
            
            
            

# fave_team_spread



# sportsbook_list2=[]
# dog_team_spread=[]

# for x in range(len(odds_json)):
#     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
#     sportsbook2= odds_json[x]["bookmakers"][x]['title']

#     if dog_spread not in dog_team_spread:
#         dog_team_spread.append(dog_spread)
#         sportsbook_list2.append(sportsbook2)

            
            

# dog_team_spread

# print(fave_team_spread)
# print(dog_team_spread)



fave_team_spread=[]
sportsbook_list=[]

for x in range(len(odds_json)):
    fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
    sportsbook= odds_json[x]["bookmakers"][x]['title']
    fave_team_spread.append(fave_spread)
    sportsbook_list.append(sportsbook)
            
            
            

fave_team_spread



sportsbook_list2=[]
dog_team_spread=[]

for x in range(len(odds_json)):
    dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
    sportsbook2= odds_json[x]["bookmakers"][x]['title']

    dog_team_spread.append(dog_spread)
    sportsbook_list2.append(sportsbook2)

            
            

dog_team_spread

print(fave_team_spread)
print(dog_team_spread)
# Out:
# [-8.5, 11.5, 4.0, -17.0, 5.5, 5.5, -12.5, -4.5, -9.0, 5.5, -8.0, 11.5]
# [8.5, -11.5, -4.0, 17.0, -5.5, -5.5, 12.5, 4.5, 9.0, -5.5, 8.0, -11.5]

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Orlando Magic',
#  'Indiana Pacers',
#  'Toronto Raptors',
#  'Brooklyn Nets',
#  'Miami Heat',
#  'Chicago Bulls',
#  'Minnesota Timberwolves',
#  'Oklahoma City Thunder',
#  'Denver Nuggets',
#  'Utah Jazz',
#  'Sacramento Kings',
#  'Phoenix Suns']

# %%
FD_Daily_Spread_Dict={"Best Sports Book(HT)":sportsbook_list,"Favorite":favorite_team_list, "Favored Team Spread":fave_team_spread,"Best Sports Book(HT)":sportsbook_list2, "Underdog Team":dog_team_list, "Underdog Team Spread":dog_team_spread, "Home Arena Belongs To":competition_site}
FD_Daily_Spread_Dict
# Out:
# {'Best Sports Book(HT)': ['Bovada',
#   'FanDuel',
#   'DraftKings',
#   'William Hill (US)',
#   'BetOnline.ag',
#   'LowVig.ag',
#   'BetMGM',
#   'MyBookie.ag',
#   'Unibet',
#   'SugarHouse',
#   'TwinSpires',
#   'BetOnline.ag'],
#  'Favorite': ['Cleveland Cavaliers',
#   'Indiana Pacers',
#   'Atlanta Hawks',
#   'Brooklyn Nets',
#   'Charlotte Hornets',
#   'Chicago Bulls',
#   'Minnesota Timberwolves',
#   'Oklahoma City Thunder',
#   'Denver Nuggets',
#   'Memphis Grizzlies',
#   'New Orleans Pelicans',
#   'Los Angeles Lakers'],
#  'Favored Team Spread': [-8.5,
#   11.5,
#   4.0,
#   -17.0,
#   5.5,
#   5.5,
#   -12.5,
#   -4.5,
#   -9.0,
#   5.5,
#   -8.0,
#   11.5],
#  'Underdog Team': ['Orlando Magic',
#   'Philadelphia 76ers',
#   'Toronto Raptors',
#   'Houston Rockets',
#   'Miami Heat',
#   'Milwaukee Bucks',
#   'Washington Wizards',
#   'Portland Trail Blazers',
#   'San Antonio Spurs',
#   'Utah Jazz',
#   'Sacramento Kings',
#   'Phoenix Suns'],
#  'Underdog Team Spread': [8.5,
#   -11.5,
#   -4.0,
#   17.0,
#   -5.5,
#   -5.5,
#   12.5,
#   4.5,
#   9.0,
#   -5.5,
#   8.0,
#   -11.5],
#  'Home Arena Belongs To': ['Orlando Magic',
#   'Indiana Pacers',
#   'Toronto Raptors',
#   'Brooklyn Nets',
#   'Miami Heat',
#   'Chicago Bulls',
#   'Minnesota Timberwolves',
#   'Oklahoma City Thunder',
#   'Denver Nuggets',
#   'Utah Jazz',
#   'Sacramento Kings',
#   'Phoenix Suns']}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['Bovada',
#  'FanDuel',
#  'DraftKings',
#  'William Hill (US)',
#  'BetOnline.ag',
#  'LowVig.ag',
#  'BetMGM',
#  'MyBookie.ag',
#  'Unibet',
#  'SugarHouse',
#  'TwinSpires',
#  'Barstool Sportsbook',
#  'BetRivers',
#  'BetUS',
#  'FOX Bet',
#  'PointsBet (US)',
#  'GTbets']

# %%
SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
#    Best Sports Book(HT)                Favorite  Favored Team Spread  \
# 0                Bovada     Cleveland Cavaliers                 -8.5
# 1               FanDuel          Indiana Pacers                 11.5
# 2            DraftKings           Atlanta Hawks                  4.0
# 3     William Hill (US)           Brooklyn Nets                -17.0
# 4          BetOnline.ag       Charlotte Hornets                  5.5
# 5             LowVig.ag           Chicago Bulls                  5.5
# 6                BetMGM  Minnesota Timberwolves                -12.5
# 7           MyBookie.ag   Oklahoma City Thunder                 -4.5
# 8                Unibet          Denver Nuggets                 -9.0
# 9            SugarHouse       Memphis Grizzlies                  5.5
# 10           TwinSpires    New Orleans Pelicans                 -8.0
# 11         BetOnline.ag      Los Angeles Lakers                 11.5
#
#              Underdog Team  Underdog Team Spread   Home Arena Belongs To
# 0            Orlando Magic                   8.5           Orlando Magic
# 1       Philadelphia 76ers                 -11.5          Indiana Pacers
# 2          Toronto Raptors                  -4.0         Toronto Raptors
# 3          Houston Rockets                  17.0           Brooklyn Nets
# 4               Miami Heat                  -5.5              Miami Heat
# 5          Milwaukee Bucks                  -5.5           Chicago Bulls
# 6       Washington Wizards                  12.5  Minnesota Timberwolves
# 7   Portland Trail Blazers                   4.5   Oklahoma City Thunder
# 8        San Antonio Spurs                   9.0          Denver Nuggets
# 9                Utah Jazz                  -5.5               Utah Jazz
# 10        Sacramento Kings                   8.0        Sacramento Kings
# 11            Phoenix Suns                 -11.5            Phoenix Suns

# %%
# Create the output file (CSV).
output_data_file = "NBA_Basketball_4.5.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
