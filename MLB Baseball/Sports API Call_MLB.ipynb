# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'baseball_mlb' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'cricket_odi', 'group': 'Cricket', 'title': 'One Day Internationals', 'description': 'One Day Internationals', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2022 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2021/2022', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'rugbyleague_nrl', 'group': 'Rugby League', 'title': 'NRL', 'description': 'Aussie Rugby League', 'active': True, 'has_outrights': False}, {'key': 'soccer_argentina_primera_division', 'group': 'Soccer', 'title': 'Primera División - Argentina', 'description': 'Argentine Primera División', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_campeonato', 'group': 'Soccer', 'title': 'Brazil Série A', 'description': 'Brasileirão Série A', 'active': True, 'has_outrights': False}, {'key': 'soccer_china_superleague', 'group': 'Soccer', 'title': 'Super League - China', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_denmark_superliga', 'group': 'Soccer', 'title': 'Denmark Superliga', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_fifa_world_cup', 'group': 'Soccer', 'title': 'FIFA World Cup', 'description': 'FIFA World Cup 2022', 'active': True, 'has_outrights': False}, {'key': 'soccer_fifa_world_cup_winner', 'group': 'Soccer', 'title': 'FIFA World Cup Winner', 'description': 'FIFA World Cup Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'soccer_finland_veikkausliiga', 'group': 'Soccer', 'title': 'Veikkausliiga - Finland', 'description': '', 'active': True, 'has_outrights': False}, {'key': 'soccer_japan_j_league', 'group': 'Soccer', 'title': 'J League', 'description': 'Japan Soccer Lea ...
# Number of events: 19
# [{'id': '18bd5d0bf8302ef68a31ac7017afb841', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-06-09T22:43:17Z', 'home_team': 'Miami Marlins', 'away_team': 'Washington Nationals', 'bookmakers': [{'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2022-06-10T00:52:43Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 145, 'point': -5.5}, {'name': 'Washington Nationals', 'price': -200, 'point': 5.5}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-06-10T00:53:50Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': -194, 'point': -4.5}, {'name': 'Washington Nationals', 'price': 148, 'point': 4.5}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-06-10T00:53:12Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': -185, 'point': -4.5}, {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2022-06-10T00:53:15Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': -200, 'point': -4.5}, {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-06-10T00:53:36Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': -186, 'point': -4.5}, {'name': 'Washington Nationals', 'price': 140, 'point': 4.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-06-10T00:52:48Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 140, 'point': -1.5}, {'name': 'Washington Nationals', 'price': -170, 'point': 1.5}]}]}, {'key': 'unibet', 'title': 'Unibet', 'last_update': '2022-06-10T00:53:17Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0}, {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2022-06-10T00:53:32Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0}, {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-06-10T00:53:46Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0}, {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-06-10T00:53:12Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0}, {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]}, {'key': 'gtbets', 'title': 'GTbets', 'last_update': '2022-06-10T00:53:25Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': -195, 'point': -4.5}, {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-06-10T00:53:02Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0}, {'name': 'Washington Nationals', 'price': -140, 'point': 5.0}]}]}]}, {'id': '5b7e06a87cd5e25855f01f6f6d3ac6f9', 'sport_key': 'baseball_mlb', 'sport_title': 'MLB', 'commence_time': '2022-06-09T23:10:07Z', 'home_team': 'Cleveland Guardians', 'away_team': 'Oakland Athletics', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-06-10T00:53:50Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cleveland Guardians', 'price': -111, 'point': 1.5}, {'name': 'Oakland Athletics', 'price': -115, 'point': -1.5}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2022-06-10T00:53:25Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Cleveland Guardians', 'price': 100, 'point': 1.5}, {'name': 'Oakland Athletics', 'price': -128, 'point': -1.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-06-10T00:53:12Z',  ...
# Remaining requests 495
# Used requests 5

# %%
# odds_json

odds_json
# Out:
# [{'id': '18bd5d0bf8302ef68a31ac7017afb841',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-09T22:43:17Z',
#   'home_team': 'Miami Marlins',
#   'away_team': 'Washington Nationals',
#   'bookmakers': [{'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:52:43Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 145, 'point': -5.5},
#        {'name': 'Washington Nationals', 'price': -200, 'point': 5.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': -194, 'point': -4.5},
#        {'name': 'Washington Nationals', 'price': 148, 'point': 4.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': -185, 'point': -4.5},
#        {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': -200, 'point': -4.5},
#        {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': -186, 'point': -4.5},
#        {'name': 'Washington Nationals', 'price': 140, 'point': 4.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 140, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -170, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#        {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#        {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#        {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#        {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': -195, 'point': -4.5},
#        {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#        {'name': 'Washington Nationals', 'price': -140, 'point': 5.0}]}]}]},
#  {'id': '5b7e06a87cd5e25855f01f6f6d3ac6f9',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-09T23:10:07Z',
#   'home_team': 'Cleveland Guardians',
#   'away_team': 'Oakland Athletics',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -111,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians', 'price': 100, 'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -128, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -103,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -124, 'point': -1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -103,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -124, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -103,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -124, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -102,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -123, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -100000,
#         'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -100000, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians', 'price': 100, 'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -130, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians', 'price': 123, 'point': 1.5},
#        {'name': 'Oakland Athletics', 'price': -158, 'point': -1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 115,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -135, 'point': 1.5}]}]}]},
#  {'id': 'bbd63d7e015de5de7a6613448758eb2f',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-09T23:21:30Z',
#   'home_team': 'Atlanta Braves',
#   'away_team': 'Pittsburgh Pirates',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -120, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -104, 'point': 2.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -120, 'point': 2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -125, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -105, 'point': 2.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -140, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 120, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -112, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -112, 'point': 2.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -360, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 255, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -360, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 250, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -375, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': 260, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -118, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -108, 'point': 2.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -115, 'point': 2.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:52:43Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -105, 'point': -2.5},
#        {'name': 'Pittsburgh Pirates', 'price': -128, 'point': 2.5}]}]}]},
#  {'id': '930215a1e907b18513ddc9da1eda6517',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-09T23:41:47Z',
#   'home_team': 'Minnesota Twins',
#   'away_team': 'New York Yankees',
#   'bookmakers': [{'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:52:43Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -133, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': 100, 'point': 3.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -135, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': 105, 'point': 3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': 104, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': -132, 'point': 3.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': 100, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': -131, 'point': 3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': 115, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -135, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -123, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': -102, 'point': 3.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -345, 'point': -1.5},
#        {'name': 'New York Yankees', 'price': 250, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -400, 'point': -1.5},
#        {'name': 'New York Yankees', 'price': 290, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -400, 'point': -1.5},
#        {'name': 'New York Yankees', 'price': 280, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -123, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': -103, 'point': 3.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -115, 'point': -3.5},
#        {'name': 'New York Yankees', 'price': -110, 'point': 3.5}]}]}]},
#  {'id': 'feb9f5f30c46717a638f9dd70c85d9be',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T00:10:50Z',
#   'home_team': 'Kansas City Royals',
#   'away_team': 'Baltimore Orioles',
#   'bookmakers': [{'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': -106, 'point': -1.0},
#        {'name': 'Kansas City Royals', 'price': -119, 'point': 1.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 135, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -180, 'point': 1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 125, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -155, 'point': 1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 125, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -159, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 125, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -159, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 125, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -159, 'point': 1.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 150, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -200, 'point': 1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 135, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -175, 'point': 1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': -200, 'point': 1.5},
#        {'name': 'Kansas City Royals', 'price': 170, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 110, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -140, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 144, 'point': -1.5},
#        {'name': 'Kansas City Royals', 'price': -186, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Orioles', 'price': 100, 'point': -1.0},
#        {'name': 'Kansas City Royals', 'price': -125, 'point': 1.0}]}]}]},
#  {'id': '7ea5e85f000c3f0346cbcd9f58d63f7b',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T01:39:00Z',
#   'home_team': 'Los Angeles Angels',
#   'away_team': 'Boston Red Sox',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-06-10T00:52:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -210, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 175, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -180, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -185, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -177, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -200, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 164, 'point': -1.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -143, 'point': 1.0},
#        {'name': 'Los Angeles Angels', 'price': 120, 'point': -1.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -182, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -180, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -190, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -190, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -196, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -200, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 165, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -205, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -210, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -137, 'point': 1.0},
#        {'name': 'Los Angeles Angels', 'price': 115, 'point': -1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -205, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -205, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-06-10T00:53:26Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Boston Red Sox', 'price': -180, 'point': 1.5},
#        {'name': 'Los Angeles Angels', 'price': 160, 'point': -1.5}]}]}]},
#  {'id': 'f7d50027dfdcbc55cd7bdc83101eed85',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:06:00Z',
#   'home_team': 'Philadelphia Phillies',
#   'away_team': 'Arizona Diamondbacks',
#   'bookmakers': [{'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -172,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 158, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -190,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -175,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -175,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 154, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -182,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -185,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -180,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -190,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -205,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -205,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -205,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -143,
#         'point': 1.0},
#        {'name': 'Philadelphia Phillies', 'price': 116, 'point': -1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -205,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -175,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Diamondbacks',
#         'price': -175,
#         'point': 1.5},
#        {'name': 'Philadelphia Phillies', 'price': 155, 'point': -1.5}]}]}]},
#  {'id': '0009b5e6e627f8baa9ed1c90698cb786',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:06:00Z',
#   'home_team': 'New York Yankees',
#   'away_team': 'Chicago Cubs',
#   'bookmakers': [{'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': 100, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -122, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': 100, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -110, 'point': -1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': 105, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -125, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -108, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -108, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -108, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -108, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Cubs', 'price': -108, 'point': 1.5},
#        {'name': 'New York Yankees', 'price': -115, 'point': -1.5}]}]}]},
#  {'id': '373b82f9b039a7350d0c2bd6cdc9c17a',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:06:00Z',
#   'home_team': 'Washington Nationals',
#   'away_team': 'Milwaukee Brewers',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -120, 'point': 1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 110, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -130, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -120, 'point': 1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': -105, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': -102, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -118, 'point': 1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -121, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': -105, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -124, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -123, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -124, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -124, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': 100, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -124, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': -105, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Milwaukee Brewers', 'price': -105, 'point': -1.5},
#        {'name': 'Washington Nationals', 'price': -115, 'point': 1.5}]}]}]},
#  {'id': '783897106b396c920fcdf56d71f7f841',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:11:00Z',
#   'home_team': 'Cleveland Guardians',
#   'away_team': 'Oakland Athletics',
#   'bookmakers': [{'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 125,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -145, 'point': 1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 125,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -145, 'point': 1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 130,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -155, 'point': 1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 135,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -156, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 134,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -162, 'point': 1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 125,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -145, 'point': 1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 139,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -151, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 125,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -155, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 130,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -162, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 130,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -162, 'point': 1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 130,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -162, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': -118,
#         'point': -1.0},
#        {'name': 'Oakland Athletics', 'price': -104, 'point': 1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 130,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -162, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 135,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -155, 'point': 1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cleveland Guardians',
#         'price': 135,
#         'point': -1.5},
#        {'name': 'Oakland Athletics', 'price': -155, 'point': 1.5}]}]}]},
#  {'id': '153c0b70798ee104b8133a30cd688eed',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:11:00Z',
#   'home_team': 'Detroit Tigers',
#   'away_team': 'Toronto Blue Jays',
#   'bookmakers': [{'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -120, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 105, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -126, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -120, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -120, 'point': -1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 105, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -121, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 105, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -125, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 102, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -127, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 102, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -127, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 102, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -127, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': -127, 'point': 2.0},
#        {'name': 'Toronto Blue Jays', 'price': 102, 'point': -2.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 102, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -127, 'point': -1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -120, 'point': -1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Tigers', 'price': 100, 'point': 1.5},
#        {'name': 'Toronto Blue Jays', 'price': -120, 'point': -1.5}]}]}]},
#  {'id': '21ee74cc948f18dd36a93c96fda9731f',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-10T23:21:00Z',
#   'home_team': 'Atlanta Braves',
#   'away_team': 'Pittsburgh Pirates',
#   'bookmakers': [{'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': 100, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -105, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -105, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -108, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -111, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -110, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -104, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -121, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -103, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -120, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -104, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -121, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -104, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -121, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -104, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -121, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Braves', 'price': -105, 'point': -1.5},
#        {'name': 'Pittsburgh Pirates', 'price': -115, 'point': 1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
# ...
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 150, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -172, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 152, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -184, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 150, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -175, 'point': 1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 150, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -180, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 155, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -190, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 160, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -200, 'point': 1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 160, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -200, 'point': 1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 112, 'point': -1.0},
#        {'name': 'Texas Rangers', 'price': -139, 'point': 1.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 160, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -200, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 160, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -200, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 150, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -170, 'point': 1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago White Sox', 'price': 150, 'point': -1.5},
#        {'name': 'Texas Rangers', 'price': -170, 'point': 1.5}]}]}]},
#  {'id': '5639cd4f685b4de092d4c38f5eb6da49',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-11T00:11:00Z',
#   'home_team': 'Minnesota Twins',
#   'away_team': 'Tampa Bay Rays',
#   'bookmakers': [{'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -170, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 145, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -178, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 146, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -170, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 145, 'point': -1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -162, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 149, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -170, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -165, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 140, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -167, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 145, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -175, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 145, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -167, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -167, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -132, 'point': 1.0},
#        {'name': 'Tampa Bay Rays', 'price': 106, 'point': -1.0}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -167, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -167, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 135, 'point': -1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Minnesota Twins', 'price': -160, 'point': 1.5},
#        {'name': 'Tampa Bay Rays', 'price': 140, 'point': -1.5}]}]}]},
#  {'id': 'f1e9aba2496b8bfc4c7fb7e9fa8c8acb',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-11T00:16:00Z',
#   'home_team': 'St. Louis Cardinals',
#   'away_team': 'Cincinnati Reds',
#   'bookmakers': [{'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -177, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -182, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -188, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -180, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -186, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -180, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -180, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 155, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -185, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 150, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -205, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -205, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -205, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -205, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 163, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -141, 'point': 1.0},
#        {'name': 'St. Louis Cardinals', 'price': 114, 'point': -1.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-06-10T00:53:25Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -180, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 160, 'point': -1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-06-10T00:53:48Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Reds', 'price': -180, 'point': 1.5},
#        {'name': 'St. Louis Cardinals', 'price': 160, 'point': -1.5}]}]}]},
#  {'id': '6696eb0d8aab3663eb33a4b040bba28c',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-11T01:41:00Z',
#   'home_team': 'San Diego Padres',
#   'away_team': 'Colorado Rockies',
#   'bookmakers': [{'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-06-10T00:53:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -105, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-06-10T00:53:21Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -105, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-06-10T00:53:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -110, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -110, 'point': -1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-06-10T00:53:09Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': 100, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -110, 'point': -1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -110, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -110, 'point': -1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': 102, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -122, 'point': -1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-06-10T00:53:36Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -110, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -110, 'point': -1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-06-10T00:53:02Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -105, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -115, 'point': -1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-06-10T00:53:38Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -109, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -114, 'point': -1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-06-10T00:53:12Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -109, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -114, 'point': -1.5}]}]},
#    {'key': 'unibet',
#     'title': 'Unibet',
#     'last_update': '2022-06-10T00:53:17Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -109, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -114, 'point': -1.5}]}]},
#    {'key': 'twinspires',
#     'title': 'TwinSpires',
#     'last_update': '2022-06-10T00:53:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -109, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -114, 'point': -1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-06-10T00:53:46Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Colorado Rockies', 'price': -109, 'point': 1.5},
#        {'name': 'San Diego Padres', 'price': -114, 'point': -1.5}]}]}]},
#  {'id': '7a745f4647c8d9101f9056313fbfa947',
#   'sport_key': 'baseball_mlb',
#   'sport_title': 'MLB',
#   'commence_time': '2022-06-11T02:16:00Z',
#   'home_team': 'San Francisco Giants',
#   'away_team': 'Los Angeles Dodgers',
#   'bookmakers': [{'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-06-10T00:53:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Los Angeles Dodgers',
#         'price': 104,
#         'point': -1.5},
#        {'name': 'San Francisco Giants', 'price': -125, 'point': 1.5}]}]}]}]

# %%
len(odds_json)
# Out:
# 19

# %%
odds_json[0]
# Out:
# {'id': '18bd5d0bf8302ef68a31ac7017afb841',
#  'sport_key': 'baseball_mlb',
#  'sport_title': 'MLB',
#  'commence_time': '2022-06-09T22:43:17Z',
#  'home_team': 'Miami Marlins',
#  'away_team': 'Washington Nationals',
#  'bookmakers': [{'key': 'foxbet',
#    'title': 'FOX Bet',
#    'last_update': '2022-06-10T00:52:43Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 145, 'point': -5.5},
#       {'name': 'Washington Nationals', 'price': -200, 'point': 5.5}]}]},
#   {'key': 'fanduel',
#    'title': 'FanDuel',
#    'last_update': '2022-06-10T00:53:50Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': -194, 'point': -4.5},
#       {'name': 'Washington Nationals', 'price': 148, 'point': 4.5}]}]},
#   {'key': 'draftkings',
#    'title': 'DraftKings',
#    'last_update': '2022-06-10T00:53:12Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': -185, 'point': -4.5},
#       {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#   {'key': 'bovada',
#    'title': 'Bovada',
#    'last_update': '2022-06-10T00:53:15Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': -200, 'point': -4.5},
#       {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#   {'key': 'pointsbetus',
#    'title': 'PointsBet (US)',
#    'last_update': '2022-06-10T00:53:36Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': -186, 'point': -4.5},
#       {'name': 'Washington Nationals', 'price': 140, 'point': 4.5}]}]},
#   {'key': 'mybookieag',
#    'title': 'MyBookie.ag',
#    'last_update': '2022-06-10T00:52:48Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 140, 'point': -1.5},
#       {'name': 'Washington Nationals', 'price': -170, 'point': 1.5}]}]},
#   {'key': 'unibet',
#    'title': 'Unibet',
#    'last_update': '2022-06-10T00:53:17Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#       {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#   {'key': 'twinspires',
#    'title': 'TwinSpires',
#    'last_update': '2022-06-10T00:53:32Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#       {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#   {'key': 'barstool',
#    'title': 'Barstool Sportsbook',
#    'last_update': '2022-06-10T00:53:46Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#       {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#   {'key': 'sugarhouse',
#    'title': 'SugarHouse',
#    'last_update': '2022-06-10T00:53:12Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#       {'name': 'Washington Nationals', 'price': -139, 'point': 5.0}]}]},
#   {'key': 'gtbets',
#    'title': 'GTbets',
#    'last_update': '2022-06-10T00:53:25Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': -195, 'point': -4.5},
#       {'name': 'Washington Nationals', 'price': 150, 'point': 4.5}]}]},
#   {'key': 'betmgm',
#    'title': 'BetMGM',
#    'last_update': '2022-06-10T00:53:02Z',
#    'markets': [{'key': 'spreads',
#      'outcomes': [{'name': 'Miami Marlins', 'price': 110, 'point': -5.0},
#       {'name': 'Washington Nationals', 'price': -140, 'point': 5.0}]}]}]}

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["home_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"],odds_json[x]["bookmakers"][0]["last_update"])
    print("----------------------")
    print(odds_json[x]["away_team"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Miami Marlins -5.5 2022-06-10T00:52:43Z
# ----------------------
# Washington Nationals 5.5
#
# ----------------------
# Cleveland Guardians 1.5 2022-06-10T00:53:50Z
# ----------------------
# Oakland Athletics -1.5
#
# ----------------------
# Atlanta Braves -2.5 2022-06-10T00:53:50Z
# ----------------------
# Pittsburgh Pirates 2.5
#
# ----------------------
# Minnesota Twins -3.5 2022-06-10T00:52:43Z
# ----------------------
# New York Yankees 3.5
#
# ----------------------
# Kansas City Royals -1.0 2022-06-10T00:53:17Z
# ----------------------
# Baltimore Orioles 1.0
#
# ----------------------
# Los Angeles Angels 1.5 2022-06-10T00:52:48Z
# ----------------------
# Boston Red Sox -1.5
#
# ----------------------
# Philadelphia Phillies 1.5 2022-06-10T00:53:09Z
# ----------------------
# Arizona Diamondbacks -1.5
#
# ----------------------
# New York Yankees 1.5 2022-06-10T00:53:19Z
# ----------------------
# Chicago Cubs -1.5
#
# ----------------------
# Washington Nationals -1.5 2022-06-10T00:53:12Z
# ----------------------
# Milwaukee Brewers 1.5
#
# ----------------------
# Cleveland Guardians -1.5 2022-06-10T00:53:19Z
# ----------------------
# Oakland Athletics 1.5
#
# ----------------------
# Detroit Tigers 1.5 2022-06-10T00:53:19Z
# ----------------------
# Toronto Blue Jays -1.5
#
# ----------------------
# Atlanta Braves -1.5 2022-06-10T00:53:36Z
# ----------------------
# Pittsburgh Pirates 1.5
#
# ----------------------
# Houston Astros -1.0 2022-06-10T00:53:17Z
# ----------------------
# Miami Marlins 1.0
#
# ----------------------
# Kansas City Royals -1.5 2022-06-10T00:53:15Z
# ----------------------
# Baltimore Orioles 1.5
#
# ----------------------
# Chicago White Sox -1.5 2022-06-10T00:53:09Z
# ----------------------
# Texas Rangers 1.5
#
# ----------------------
# Minnesota Twins 1.5 2022-06-10T00:53:15Z
# ----------------------
# Tampa Bay Rays -1.5
#
# ----------------------
# St. Louis Cardinals 1.5 2022-06-10T00:53:09Z
# ----------------------
# Cincinnati Reds -1.5
#
# ----------------------
# San Diego Padres 1.5 2022-06-10T00:53:15Z
# ----------------------
# Colorado Rockies -1.5
#
# ----------------------
# San Francisco Giants -1.5 2022-06-10T00:53:50Z
# ----------------------
# Los Angeles Dodgers 1.5

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# []

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# []

# %%
# fave_team_spread=[]
# sportsbook_list=[]

# for x in range(len(odds_json)):
#     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
#     sportsbook= odds_json[x]["bookmakers"][x]['title']
#     if fave_spread not in fave_team_spread:
#         fave_team_spread.append(fave_spread)
#         sportsbook_list.append(sportsbook)
            
            
            

# fave_team_spread



# sportsbook_list2=[]
# dog_team_spread=[]

# for x in range(len(odds_json)):
#     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
#     sportsbook2= odds_json[x]["bookmakers"][x]['title']

#     if dog_spread not in dog_team_spread:
#         dog_team_spread.append(dog_spread)
#         sportsbook_list2.append(sportsbook2)

            
            

# dog_team_spread

# print(fave_team_spread)
# print(dog_team_spread)



home_team_spread=[]
sportsbook_list=[]

for x in range(len(odds_json)):
    fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
    sportsbook= odds_json[x]["bookmakers"][x]['title']
    home_team_spread.append(fave_spread)
    sportsbook_list.append(sportsbook)
            
            
            

home_team_spread



sportsbook_list2=[]
away_team_spread=[]

for x in range(len(odds_json)):
    dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
    sportsbook2= odds_json[x]["bookmakers"][x]['title']

    away_team_spread.append(dog_spread)
    sportsbook_list2.append(sportsbook2)

            
            

away_team_spread

print(home_team_spread)
print(away_team_spread)
# Out:
# []
# []

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# []

# %%
FD_Daily_Spread_Dict={"Best Sports Book(HT)":sportsbook_list,"Home_Team":home_team_list, "Home Team Spread":home_team_spread,"Best Sports Book(HT)":sportsbook_list2, "Away_Team":away_team_list, "Away Team Spread":away_team_spread, "Home Arena Belongs To":competition_site}
FD_Daily_Spread_Dict
# Out:
# {'Best Sports Book(HT)': [],
#  'Home_Team': [],
#  'Home Team Spread': [],
#  'Away_Team': [],
#  'Away Team Spread': [],
#  'Home Arena Belongs To': []}

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_1793/1495882321.py in <module>
#       1 SB_Operators=[]
#       2
# ----> 3 for x in range(len(odds_json[0]["bookmakers"])):
#       4     SB_Operator = odds_json[0]["bookmakers"][x]["title"]
#       5     if SB_Operator not in SB_Operators:
#
# IndexError: list index out of range

# %%
# This layout is perfect for volume bettors who bet smaller units across multiple games

SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
# Empty DataFrame
# Columns: [Best Sports Book(HT), Home_Team, Home Team Spread, Away_Team, Away Team Spread, Home Arena Belongs To]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WNBA_Basketball_6.9.2022.xlsx"
# Export the City_Data into a Excel File for later analysis
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
