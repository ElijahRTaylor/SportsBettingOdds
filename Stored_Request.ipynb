# %%
import pandas as pd

# %%
Monday_Spread_df=pd.read_excel("NBA_Basketball_Monday_3.21_LATE_GAME_CHANGES.xlsx")
Monday_Spread_df.head(10)
# Out:
#    id Best Sports Book(HT)             Favorite  Favored Team Spread  \
# 0   0              FanDuel    Charlotte Hornets                 -6.0
# 1   1              WynnBET  Cleveland Cavaliers                 -4.5
# 2   2              FanDuel      Detroit Pistons                -10.0
# 3   3              FanDuel        Brooklyn Nets                  2.0
# 4   4            BetRivers           Miami Heat                 -8.0
# 5   5    William Hill (US)       Boston Celtics                -14.5
# 6   6           TwinSpires        Chicago Bulls                 -4.0
# 7   7            BetRivers      Houston Rockets                  5.0
# 8   8            LowVig.ag     Dallas Mavericks                 -2.0
#
#             Underdog Team  Underdog Team Spread  Home Arena Belongs To
# 0    New Orleans Pelicans                   6.0      Charlotte Hornets
# 1      Los Angeles Lakers                   4.5    Cleveland Cavaliers
# ...

# %%
Monday_Original_df=pd.read_excel("NBA_Basketball_Monday_3.21.xlsx")
Monday_Original_df.head()
# Out:
#   Best Sports Book(HT)             Favorite  Favored Team Spread  \
# 0              FanDuel    Charlotte Hornets                 -6.0
# 1              FanDuel  Cleveland Cavaliers                 -6.0
# 2              FanDuel      Detroit Pistons                 -7.5
# 3               Unibet           Miami Heat                 -1.0
# 4              WynnBET        Brooklyn Nets                 -1.0
#
#             Underdog Team  Underdog Team Spread Home Arena Belongs To
# 0    New Orleans Pelicans                   6.0     Charlotte Hornets
# 1      Los Angeles Lakers                   6.0   Cleveland Cavaliers
# 2  Portland Trail Blazers                   7.5       Detroit Pistons
# 3      Philadelphia 76ers                   1.0    Philadelphia 76ers
# 4               Utah Jazz                   1.0         Brooklyn Nets
