# %%
import requests
import json
import pandas as pd

from config import sports_key

# %%
# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
#API_KEY = 'YOUR_API_KEY'

SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': sports_key
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': sports_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)



if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# List of in season sports: [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2022', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'cricket_icc_world_cup', 'group': 'Cricket', 'title': 'ICC World Cup', 'description': 'ICC World Cup', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_the_open_championship_winner', 'group': 'Golf', 'title': 'The Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_us_open_winner', 'group': 'Golf', 'title': 'US Open Winner', 'description': '2023 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2022/2023', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'soccer_australia_aleague', 'group': 'Soccer', 'title': 'A-League', 'description': 'Aussie Soccer', 'active': True, 'has_outrights': False}, {'key': 'soccer_belgium_first_div', 'group': 'Soccer', 'title': 'Belgium First Div', 'description': 'Belgian First Division A', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_campeonato', 'group': 'Soccer', 'title': 'Brazil Série A', 'description': 'Brasileirão Série A', 'active': True, 'has_outrights': False}, {'key': 'soccer_brazil_serie_b', 'group': 'Soccer', 'title': 'Brazil Série B', 'description': 'Campeonato Brasileiro Série B', 'active': True, 'has_outrights': False}, {'key': 'soccer_chile_campeonato', 'group': 'Soccer', 'title': 'Primera División - Chile', 'description': 'Campeonato Chileno', 'active': True, 'has_outrights': False}, {'key': 'soccer_china_superleague', 'group ...
# Number of events: 15
# [{'id': '8838f455ed167736eda069f20e4315a6', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2022-10-28T00:15:00Z', 'home_team': 'Tampa Bay Buccaneers', 'away_team': 'Baltimore Ravens', 'bookmakers': [{'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2022-10-26T03:06:55Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -111, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -111, 'point': 1.5}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-10-26T03:07:24Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-10-26T03:07:29Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0}, {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-10-26T03:07:29Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -115, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': 100, 'point': 1.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-10-26T03:08:37Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-10-26T03:07:29Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0}, {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-10-26T03:06:32Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -2.0}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 2.0}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-10-26T03:06:55Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0}, {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2022-10-26T03:06:55Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2022-10-26T03:07:30Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0}, {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-10-26T03:06:32Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2022-10-26T03:04:07Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -105, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -105, 'point': 1.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2022-10-26T03:06:18Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2022-10-26T03:04:50Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5}, {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}, {'key': 'circasports', 'title': 'Circa Sports', 'last_update': '2022-10-26T03:06:55Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 100, 'point': -2.5}, {'name': 'Tampa Bay ...
# Remaining requests 496
# Used requests 4

# %%
# odds_json

odds_json
# Out:
# [{'id': '8838f455ed167736eda069f20e4315a6',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-28T00:15:00Z',
#   'home_team': 'Tampa Bay Buccaneers',
#   'away_team': 'Baltimore Ravens',
#   'bookmakers': [{'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -111, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -111, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -115, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': 100, 'point': 1.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -2.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -113, 'point': -1.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -108, 'point': 1.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -105, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -105, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': 100, 'point': -2.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -118, 'point': 2.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -2.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -109, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Baltimore Ravens', 'price': -110, 'point': -1.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': -110, 'point': 1.5}]}]}]},
#  {'id': '0c056485fc7897af7947e667069e420b',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T13:30:00Z',
#   'home_team': 'Jacksonville Jaguars',
#   'away_team': 'Denver Broncos',
#   'bookmakers': [{'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -111, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -111, 'point': -2.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -106, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -102, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -108, 'point': -2.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -106, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -106, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -106, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -107, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -112, 'point': -2.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -115, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -105, 'point': -2.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -120, 'point': 3.0},
#        {'name': 'Jacksonville Jaguars', 'price': 100, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -109, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -109, 'point': -2.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -105, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -115, 'point': -2.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Denver Broncos', 'price': -110, 'point': 2.5},
#        {'name': 'Jacksonville Jaguars', 'price': -110, 'point': -2.5}]}]}]},
#  {'id': 'fbef1db7e3116a12749166bf3f1e0d64',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'Minnesota Vikings',
#   'away_team': 'Arizona Cardinals',
#   'bookmakers': [{'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 4.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -115, 'point': 4.0},
#        {'name': 'Minnesota Vikings', 'price': -105, 'point': -4.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -107, 'point': -3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -106, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -114, 'point': -3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': 100, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -105, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -115, 'point': -3.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 4.0},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -4.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -107, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -112, 'point': -3.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -109, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -105, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -118, 'point': -3.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Arizona Cardinals', 'price': -110, 'point': 3.5},
#        {'name': 'Minnesota Vikings', 'price': -110, 'point': -3.5}]}]}]},
#  {'id': '24343288ee1dd1405d89fe88a0aec57c',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'Atlanta Falcons',
#   'away_team': 'Carolina Panthers',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -107, 'point': -5.0},
#        {'name': 'Carolina Panthers', 'price': -107, 'point': 5.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 4.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 4.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 4.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 4.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -5.0},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 5.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -105, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -105, 'point': 4.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -112, 'point': 4.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -109, 'point': 4.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -109, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -109, 'point': 4.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Atlanta Falcons', 'price': -110, 'point': -4.5},
#        {'name': 'Carolina Panthers', 'price': -110, 'point': 4.5}]}]}]},
#  {'id': '127cac8c3221336aa38df5b846f2dbeb',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'Dallas Cowboys',
#   'away_team': 'Chicago Bears',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.0},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -120, 'point': 10.0},
#        {'name': 'Dallas Cowboys', 'price': 100, 'point': -10.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -105, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -118, 'point': -9.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -105, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -115, 'point': -9.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.0},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -109, 'point': 9.0},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -105, 'point': -9.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -112, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -112, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -112, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -112, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -111, 'point': 9.0},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -106, 'point': 9.0},
#        {'name': 'Dallas Cowboys', 'price': -104, 'point': -9.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -110, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -110, 'point': -9.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Chicago Bears', 'price': -109, 'point': 9.5},
#        {'name': 'Dallas Cowboys', 'price': -109, 'point': -9.5}]}]}]},
#  {'id': 'cf7283279795f05bff660461617d6825',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'Detroit Lions',
#   'away_team': 'Miami Dolphins',
#   'bookmakers': [{'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -105, 'point': -3.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -105, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -115, 'point': -3.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -105, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -115, 'point': -3.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -104, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -106, 'point': -3.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -111, 'point': -3.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': 108, 'point': 3.0},
#        {'name': 'Miami Dolphins', 'price': -129, 'point': -3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -109, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -109, 'point': -3.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': 3.5},
#        {'name': 'Miami Dolphins', 'price': -110, 'point': -3.5}]}]}]},
#  {'id': '767ca7cda3e3ade1887e30671d5fc213',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'New Orleans Saints',
#   'away_team': 'Las Vegas Raiders',
#   'bookmakers': [{'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -105, 'point': 2.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -114, 'point': -1.5},
#        {'name': 'New Orleans Saints', 'price': -106, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -107, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -103, 'point': 2.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -112, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': 2.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -115, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -105, 'point': 2.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': 100, 'point': -2.5},
#        {'name': 'New Orleans Saints', 'price': -118, 'point': 2.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -115, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -105, 'point': 2.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -109, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -109, 'point': 2.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -118, 'point': -1.5},
#        {'name': 'New Orleans Saints', 'price': -105, 'point': 1.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Las Vegas Raiders', 'price': -110, 'point': -2.0},
#        {'name': 'New Orleans Saints', 'price': -110, 'point': 2.0}]}]}]},
#  {'id': '93ce7a34b4c443ac8035319a061de0a9',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'New York Jets',
#   'away_team': 'New England Patriots',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -107,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -103, 'point': 1.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': 100,
#         'point': -2.5},
#        {'name': 'New York Jets', 'price': -118, 'point': 2.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -112,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -107,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -107, 'point': 1.5}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -125,
#         'point': -1.0},
#        {'name': 'New York Jets', 'price': 105, 'point': 1.0}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -2.0},
#        {'name': 'New York Jets', 'price': -110, 'point': 2.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -110,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -110, 'point': 1.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New England Patriots',
#         'price': -109,
#         'point': -1.5},
#        {'name': 'New York Jets', 'price': -109, 'point': 1.5}]}]}]},
#  {'id': 'acf99d213b4af0eef3ef32a7a7349934',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-30T17:00:00Z',
#   'home_team': 'Philadelphia Eagles',
#   'away_team': 'Pittsburgh Steelers',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -10.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -10.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -10.5},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -110,
#         'point': -11.0},
#        {'name': 'Pittsburgh Steelers', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Philadelphia Eagles',
#         'price': -115,
#         'point': -10.5},
# ...
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -109, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -109, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -112, 'point': -3.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -108, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -102, 'point': -3.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -113, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -115, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -105, 'point': -3.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -107, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -107, 'point': -3.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -109, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -109, 'point': -3.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'New York Giants', 'price': -110, 'point': 3.0},
#        {'name': 'Seattle Seahawks', 'price': -110, 'point': -3.0}]}]}]},
#  {'id': '5babc5df2e2dbae5ce7baec2e5628330',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-10-31T00:20:00Z',
#   'home_team': 'Buffalo Bills',
#   'away_team': 'Green Bay Packers',
#   'bookmakers': [{'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.5},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.5}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -109, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -112, 'point': 11.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -112, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -109, 'point': 10.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -112, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -109, 'point': 10.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -112, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -109, 'point': 10.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.5},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -112, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -109, 'point': 10.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -107, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -107, 'point': 10.5}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -103, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -107, 'point': 11.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -107, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -112, 'point': 10.5}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 105, 'point': -12.0},
#        {'name': 'Green Bay Packers', 'price': -125, 'point': 12.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -12.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 12.0}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -109, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -109, 'point': 11.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -10.5},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 10.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': -110, 'point': -11.0},
#        {'name': 'Green Bay Packers', 'price': -110, 'point': 11.0}]}]}]},
#  {'id': '67e7b19f194b1cc4b653f6bd45b6521a',
#   'sport_key': 'americanfootball_nfl',
#   'sport_title': 'NFL',
#   'commence_time': '2022-11-01T00:15:00Z',
#   'home_team': 'Cleveland Browns',
#   'away_team': 'Cincinnati Bengals',
#   'bookmakers': [{'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T03:04:07Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -103,
#         'point': -4.0},
#        {'name': 'Cleveland Browns', 'price': -107, 'point': 4.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -4.0},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 4.0}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T03:06:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 3.5}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 3.5}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 3.5}]}]},
#    {'key': 'superbook',
#     'title': 'SuperBook',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T03:07:30Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 3.5}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T03:08:37Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T03:07:24Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -115,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 3.5}]}]},
#    {'key': 'wynnbet',
#     'title': 'WynnBET',
#     'last_update': '2022-10-26T03:06:32Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'bovada',
#     'title': 'Bovada',
#     'last_update': '2022-10-26T03:04:50Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T03:06:55Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -107,
#         'point': -4.0},
#        {'name': 'Cleveland Browns', 'price': -112, 'point': 4.0}]}]},
#    {'key': 'betus',
#     'title': 'BetUS',
#     'last_update': '2022-10-26T03:05:35Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -105,
#         'point': -4.0},
#        {'name': 'Cleveland Browns', 'price': -115, 'point': 4.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T03:08:18Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T03:07:29Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 3.5}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2022-10-26T03:08:57Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -109,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -109, 'point': 3.5}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T03:06:15Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -118,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -105, 'point': 3.5}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T03:07:19Z',
#     'markets': [{'key': 'spreads',
#       'outcomes': [{'name': 'Cincinnati Bengals',
#         'price': -110,
#         'point': -3.5},
#        {'name': 'Cleveland Browns', 'price': -110, 'point': 3.5}]}]}]}]

# %%
len(odds_json)
# Out:
# 15

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Baltimore Ravens -1.5
# ----------------------
# Tampa Bay Buccaneers 1.5
#
# ----------------------
# Denver Broncos 2.5
# ----------------------
# Jacksonville Jaguars -2.5
#
# ----------------------
# Arizona Cardinals 3.5
# ----------------------
# Minnesota Vikings -3.5
#
# ----------------------
# Atlanta Falcons -4.5
# ----------------------
# Carolina Panthers 4.5
#
# ----------------------
# Chicago Bears 9.0
# ----------------------
# Dallas Cowboys -9.0
#
# ----------------------
# Detroit Lions 3.5
# ----------------------
# Miami Dolphins -3.5
#
# ----------------------
# Las Vegas Raiders -2.0
# ----------------------
# New Orleans Saints 2.0
#
# ----------------------
# New England Patriots -1.5
# ----------------------
# New York Jets 1.5
#
# ----------------------
# Philadelphia Eagles -10.5
# ----------------------
# Pittsburgh Steelers 10.5
#
# ----------------------
# Houston Texans 2.0
# ----------------------
# Tennessee Titans -2.0
#
# ----------------------
# Indianapolis Colts -2.5
# ----------------------
# Washington Commanders 2.5
#
# ----------------------
# Los Angeles Rams 1.0
# ----------------------
# San Francisco 49ers -1.0
#
# ----------------------
# New York Giants 3.0
# ----------------------
# Seattle Seahawks -3.0
#
# ----------------------
# Buffalo Bills -11.5
# ----------------------
# Green Bay Packers 11.5
#
# ----------------------
# Cincinnati Bengals -4.0
# ----------------------
# Cleveland Browns 4.0

# %%
print(odds_json[0]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# Baltimore Ravens

# %%
# Create for loop to iterate through each basketball game.  We want home team, 
print("FANDUEL LIVE ODDS")
print("")
for x in range(len(odds_json)):
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][0]["point"])
    print("----------------------")
    print(odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["name"],odds_json[x]["bookmakers"][0]["markets"][0]["outcomes"][1]["point"])
    print("                      ")
# Out:
# FANDUEL LIVE ODDS
#
# ----------------------
# Baltimore Ravens -1.5
# ----------------------
# Tampa Bay Buccaneers 1.5
#
# ----------------------
# Denver Broncos 2.5
# ----------------------
# Jacksonville Jaguars -2.5
#
# ----------------------
# Arizona Cardinals 3.5
# ----------------------
# Minnesota Vikings -3.5
#
# ----------------------
# Atlanta Falcons -4.5
# ----------------------
# Carolina Panthers 4.5
#
# ----------------------
# Chicago Bears 9.0
# ----------------------
# Dallas Cowboys -9.0
#
# ----------------------
# Detroit Lions 3.5
# ----------------------
# Miami Dolphins -3.5
#
# ----------------------
# Las Vegas Raiders -2.0
# ----------------------
# New Orleans Saints 2.0
#
# ----------------------
# New England Patriots -1.5
# ----------------------
# New York Jets 1.5
#
# ----------------------
# Philadelphia Eagles -10.5
# ----------------------
# Pittsburgh Steelers 10.5
#
# ----------------------
# Houston Texans 2.0
# ----------------------
# Tennessee Titans -2.0
#
# ----------------------
# Indianapolis Colts -2.5
# ----------------------
# Washington Commanders 2.5
#
# ----------------------
# Los Angeles Rams 1.0
# ----------------------
# San Francisco 49ers -1.0
#
# ----------------------
# New York Giants 3.0
# ----------------------
# Seattle Seahawks -3.0
#
# ----------------------
# Buffalo Bills -11.5
# ----------------------
# Green Bay Packers 11.5
#
# ----------------------
# Cincinnati Bengals -4.0
# ----------------------
# Cleveland Browns 4.0

# %%
print(odds_json[9]["bookmakers"][0]["markets"][0]["outcomes"][0]["name"])
# Out:
# Houston Texans

# %%
# Iterate through all of the home teams and save to list

home_team_list=[]

for x in range(len(odds_json)):
    home_team = odds_json[x]["home_team"]
    if home_team not in home_team_list:
                 home_team_list.append(home_team)
                     
home_team_list

# favored_team_test = (odds_json[8]["bookmakers"][0]["markets"][0]["outcomes"][0]['name'])

# favored_team_test
# Out:
# ['Tampa Bay Buccaneers',
#  'Jacksonville Jaguars',
#  'Minnesota Vikings',
#  'Atlanta Falcons',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Los Angeles Rams',
#  'Seattle Seahawks',
#  'Buffalo Bills',
#  'Cleveland Browns']

# %%
# Iterate through all of the away teams and save to list

away_team_list=[]

for x in range(len(odds_json)):
    away_team = odds_json[x]["away_team"]
    if away_team not in away_team_list:
                 away_team_list.append(away_team)
            
away_team_list
# Out:
# ['Baltimore Ravens',
#  'Denver Broncos',
#  'Arizona Cardinals',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Miami Dolphins',
#  'Las Vegas Raiders',
#  'New England Patriots',
#  'Pittsburgh Steelers',
#  'Tennessee Titans',
#  'Washington Commanders',
#  'San Francisco 49ers',
#  'New York Giants',
#  'Green Bay Packers',
#  'Cincinnati Bengals']

# %%
# # fave_team_spread=[]
# # sportsbook_list=[]

# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     if fave_spread not in fave_team_spread:
# #         fave_team_spread.append(fave_spread)
# #         sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     if dog_spread not in dog_team_spread:
# #         dog_team_spread.append(dog_spread)
# #         sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# # print(dog_team_spread)


# # fave_team_spread=[]
sportsbook_list=[]

# odds_json[0]["bookmakers"]
for x in range(len(odds_json[0]["bookmakers"])):
    sportsbook=odds_json[0]["bookmakers"][x]["title"]
    sportsbook_list.append(sportsbook)

print(sportsbook_list)
    
    




# # for x in range(len(odds_json)):
# #     fave_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][0]["point"]
# #     sportsbook= odds_json[x]["bookmakers"][x]['title']
# #     fave_team_spread.append(fave_spread)
# #     sportsbook_list.append(sportsbook)
            
            
            

# # fave_team_spread



# # sportsbook_list2=[]
# # dog_team_spread=[]

# # for x in range(len(odds_json)):
# #     dog_spread = odds_json[x]["bookmakers"][x]["markets"][0]["outcomes"][1]["point"]
# #     sportsbook2= odds_json[x]["bookmakers"][x]['title']

# #     dog_team_spread.append(dog_spread)
# #     sportsbook_list2.append(sportsbook2)

            
            

# # dog_team_spread

# # print(fave_team_spread)
# print(dog_team_spread)
# Out:
# ['BetOnline.ag', 'FanDuel', 'BetRivers', 'PointsBet (US)', 'MyBookie.ag', 'SugarHouse', 'WynnBET', 'Barstool Sportsbook', 'SuperBook', 'Unibet', 'DraftKings', 'LowVig.ag', 'William Hill (US)', 'Bovada', 'Circa Sports', 'BetUS', 'BetMGM', 'GTbets', 'FOX Bet', 'Intertops']

# %%
competition_site=[]

for x in range(len(odds_json)):
    home_arena = odds_json[x]["home_team"]
    if home_arena not in competition_site:
        competition_site.append(home_arena)

competition_site
# Out:
# ['Tampa Bay Buccaneers',
#  'Jacksonville Jaguars',
#  'Minnesota Vikings',
#  'Atlanta Falcons',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Los Angeles Rams',
#  'Seattle Seahawks',
#  'Buffalo Bills',
#  'Cleveland Browns']

# %% [markdown]
# # FD_Daily_Spread_Dict={"Best Sports Book(HT)":sportsbook_list,"Home_Team":home_team_list, "Favored Team Spread":fave_team_spread,"Best Sports Book(HT)":sportsbook_list2, "Away_Team":away_team_list, "Underdog Team Spread":dog_team_spread, "Home Arena Belongs To":competition_site}
# FD_Daily_Spread_Dict

# %%
SB_Operators=[]

for x in range(len(odds_json[0]["bookmakers"])):
    SB_Operator = odds_json[0]["bookmakers"][x]["title"]
    if SB_Operator not in SB_Operators:
                 SB_Operators.append(SB_Operator)

SB_Operators
# Out:
# ['BetOnline.ag',
#  'FanDuel',
#  'BetRivers',
#  'PointsBet (US)',
#  'MyBookie.ag',
#  'SugarHouse',
#  'WynnBET',
#  'Barstool Sportsbook',
#  'SuperBook',
#  'Unibet',
#  'DraftKings',
#  'LowVig.ag',
#  'William Hill (US)',
#  'Bovada',
#  'Circa Sports',
#  'BetUS',
#  'BetMGM',
#  'GTbets',
#  'FOX Bet',
#  'Intertops']

# %%
# This layout is perfect for volume bettors who bet smaller units across multiple games

SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
SB_NBA_Odds_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_1424/2524627083.py in <module>
#       1 # This layout is perfect for volume bettors who bet smaller units across multiple games
#       2
# ----> 3 SB_NBA_Odds_df=pd.DataFrame(FD_Daily_Spread_Dict)
#       4 SB_NBA_Odds_df
#
# NameError: name 'FD_Daily_Spread_Dict' is not defined

# %%
# Create the output file (CSV).
output_data_file = "NBA_Basketball_4.5.xlsx"
# Export the City_Data into a CSV.
SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/n_v9bfk51q1bd2l68g7v1fl00000gn/T/ipykernel_1198/3542148122.py in <module>
#       2 output_data_file = "NBA_Basketball_4.5.xlsx"
#       3 # Export the City_Data into a CSV.
# ----> 4 SB_NBA_Odds_df.to_excel(output_data_file, index_label="id")
#
# NameError: name 'SB_NBA_Odds_df' is not defined
